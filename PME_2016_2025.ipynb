# %% [markdown]
# <a href="https://colab.research.google.com/github/AyrtonJYT/YANAPAY_ANALISIS_ENERGETICO/blob/main/PME_2016_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TABLA 1_1 CASO BASE POTENCIA

# %%
# import pandas as pd

# # Datos extraídos de la tabla
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
#     'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
#     'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861],
#     'Crecimiento (%) - Medio': [0.0, 2.2, 7.6, 7.1, 6.5, 6.1, 5.8, 5.2, 4.1, 4.5] # 0.0 para 2016 ya que no hay dato base anterior
# }

# # Creación del DataFrame
# df_energia = pd.DataFrame(data)

# # Establecer el Año como índice y convertir las demandas a miles para mejor manejo (aunque ya son números flotantes)
# # Multiplicar por 1000 para trabajar con los valores como enteros si fuera necesario, pero se mantendrán flotantes.
# df_energia['Demanda (GWh) - Menor'] = df_energia['Demanda (GWh) - Menor'] * 1000
# df_energia['Demanda (GWh) - Medio'] = df_energia['Demanda (GWh) - Medio'] * 1000
# df_energia['Demanda (GWh) - Mayor'] = df_energia['Demanda (GWh) - Mayor'] * 1000

# # Renombrar columnas para reflejar el cambio de escala a MWh si el usuario lo quisiera,
# # pero en este caso se mantiene GWh y se usa el valor original (23.518 GWh)
# # Si se multiplica por 1000, 23.518 GWh = 23,518 MWh. Las unidades se mantendrán GWh para seguir la tabla.

# df_energia.set_index('Año', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Previsión de la Demanda Anual de Energía Eléctrica (GWh * 1000):")
# print(df_energia)

# %%
# import pandas as pd

# # Datos extraídos de la tabla
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3653, 3947, 4205, 4456, 4663, 4865, 5074, 5240, 5372, 5409],
#     'Demanda (MW) - Medio': [3653, 3987, 4290, 4585, 4839, 5091, 5355, 5579, 5773, 5868],
#     'Demanda (MW) - Mayor': [3653, 4020, 4359, 4693, 4989, 5286, 5601, 5878, 6130, 6285],
#     'Crecimiento (%) - Medio': [0.0, 9.2, 7.6, 6.9, 5.5, 5.2, 5.2, 4.2, 3.5, 1.6] # 0.0 para 2016 ya que no hay dato base anterior
# }

# # Creación del DataFrame
# df_prevision = pd.DataFrame(data)

# # Establecer el Año como índice
# df_prevision.set_index('Año', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Previsión de la Demanda Anual de Potencia Eléctrica:")
# print(df_prevision)

# %% [markdown]
# TABLA 1_2 CASO BASE ENERGÍA

# %%
# import pandas as pd

# # Datos extraídos de la tabla
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
#     'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
#     'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861],
#     'Crecimiento (%) - Medio': [0.0, 2.2, 7.6, 7.1, 6.5, 6.1, 5.8, 5.2, 4.1, 4.5] # 0.0 para 2016 ya que no hay dato base anterior
# }

# # Creación del DataFrame
# df_energia = pd.DataFrame(data)

# # Establecer el Año como índice y convertir las demandas a miles para mejor manejo (aunque ya son números flotantes)
# # Multiplicar por 1000 para trabajar con los valores como enteros si fuera necesario, pero se mantendrán flotantes.
# df_energia['Demanda (GWh) - Menor'] = df_energia['Demanda (GWh) - Menor'] * 1000
# df_energia['Demanda (GWh) - Medio'] = df_energia['Demanda (GWh) - Medio'] * 1000
# df_energia['Demanda (GWh) - Mayor'] = df_energia['Demanda (GWh) - Mayor'] * 1000

# # Renombrar columnas para reflejar el cambio de escala a MWh si el usuario lo quisiera,
# # pero en este caso se mantiene GWh y se usa el valor original (23.518 GWh)
# # Si se multiplica por 1000, 23.518 GWh = 23,518 MWh. Las unidades se mantendrán GWh para seguir la tabla.

# df_energia.set_index('Año', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Previsión de la Demanda Anual de Energía Eléctrica (GWh * 1000):")
# print(df_energia)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos y DataFrame (mismo del Paso 3)
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
#     'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
#     'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861],
# }

# df_energia = pd.DataFrame(data)
# df_energia.set_index('Año', inplace=True)

# # Generación del gráfico de líneas para los tres escenarios de demanda
# plt.figure(figsize=(12, 6))

# # Trazado de las líneas
# plt.plot(df_energia.index, df_energia['Demanda (GWh) - Menor'], label='Escenario Menor', marker='s', linestyle='--')
# plt.plot(df_energia.index, df_energia['Demanda (GWh) - Medio'], label='Escenario Medio', marker='o', linestyle='-')
# plt.plot(df_energia.index, df_energia['Demanda (GWh) - Mayor'], label='Escenario Mayor', marker='^', linestyle='-.')

# # Añadir título y etiquetas
# plt.title('Previsión de la Demanda Anual de Energía Eléctrica (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda de Energía (GWh)', fontsize=12)

# # Configuración del eje X (mostrar todos los años)
# plt.xticks(df_energia.index)

# # Añadir leyenda y cuadrícula
# plt.legend(title='Escenario de Previsión')
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# tABLA 1_3 PROYECCION DE LA DEMANDA ANUAL DE POTENCIA

# %%
# import pandas as pd

# # Datos extraídos de la tabla para la Demanda de Potencia (MW)
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3653, 3948, 4211, 4481, 4691, 4895, 5115, 5724, 6252, 6684],
#     'Demanda (MW) - Medio': [3653, 3988, 4295, 4610, 4867, 5120, 5396, 6064, 6653, 7144],
#     'Demanda (MW) - Mayor': [3653, 4022, 4364, 4718, 5017, 5316, 5642, 6363, 7010, 7560],
#     # Incluimos la tasa de crecimiento medio para referencia
#     'Crecimiento (%) - Medio': [0.0, 9.2, 7.7, 7.3, 5.6, 5.2, 5.4, 12.4, 9.7, 7.4]
# }

# # Creación del DataFrame
# df_potencia_hipotesis5 = pd.DataFrame(data)

# # Establecer el Año como índice
# df_potencia_hipotesis5.set_index('Año', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Previsión de la Demanda Anual de Potencia Eléctrica (Hipótesis No. 5):")
# print(df_potencia_hipotesis5)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos y DataFrame (mismo del Paso 3)
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3653, 3948, 4211, 4481, 4691, 4895, 5115, 5724, 6252, 6684],
#     'Demanda (MW) - Medio': [3653, 3988, 4295, 4610, 4867, 5120, 5396, 6064, 6653, 7144],
#     'Demanda (MW) - Mayor': [3653, 4022, 4364, 4718, 5017, 5316, 5642, 6363, 7010, 7560],
# }

# df_potencia_hipotesis5 = pd.DataFrame(data)
# df_potencia_hipotesis5.set_index('Año', inplace=True)

# # Generación del gráfico de líneas para los tres escenarios de demanda
# plt.figure(figsize=(12, 6))

# # Trazado de las líneas
# plt.plot(df_potencia_hipotesis5.index, df_potencia_hipotesis5['Demanda (MW) - Menor'], label='Escenario Menor', marker='o', linestyle='--')
# plt.plot(df_potencia_hipotesis5.index, df_potencia_hipotesis5['Demanda (MW) - Medio'], label='Escenario Medio', marker='o', linestyle='-')
# plt.plot(df_potencia_hipotesis5.index, df_potencia_hipotesis5['Demanda (MW) - Mayor'], label='Escenario Mayor', marker='o', linestyle='-.')

# # Añadir título y etiquetas
# plt.title('Previsión de la Demanda Anual de Potencia Eléctrica (Hipótesis No. 5: 2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda de Potencia (MW)', fontsize=12)

# # Configuración del eje X (mostrar todos los años)
# plt.xticks(df_potencia_hipotesis5.index)

# # Añadir leyenda y cuadrícula
# plt.legend(title='Escenario de Previsión')
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %%
TABLA 1_4: PROYECCION DE LA DEMANDA ANUAL DE ENERGÍA

# %%
# import pandas as pd

# # Datos extraídos de la tabla para la Demanda de Energía (GWh)
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.800, 25.395, 27.088, 28.669, 30.164, 31.721, 35.837, 40.329, 44.898],
#     'Demanda (GWh) - Medio': [23.518, 24.050, 25.917, 27.881, 29.765, 31.579, 33.497, 37.999, 42.901, 47.906],
#     'Demanda (GWh) - Mayor': [23.518, 24.272, 26.380, 28.609, 30.782, 32.916, 35.188, 40.074, 45.395, 50.854],
#     # Incluimos la tasa de crecimiento medio para referencia
#     'Crecimiento (%) - Medio': [0.0, 2.3, 7.8, 7.6, 6.8, 6.1, 6.1, 13.4, 12.9, 11.7]
# }

# # Creación del DataFrame
# df_energia_hipotesis5 = pd.DataFrame(data)

# # Establecer el Año como índice
# df_energia_hipotesis5.set_index('Año', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Previsión de la Demanda Anual de Energía Eléctrica (Hipótesis No. 5):")
# print(df_energia_hipotesis5)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos y DataFrame (mismo del Paso 3)
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.800, 25.395, 27.088, 28.669, 30.164, 31.721, 35.837, 40.329, 44.898],
#     'Demanda (GWh) - Medio': [23.518, 24.050, 25.917, 27.881, 29.765, 31.579, 33.497, 37.999, 42.901, 47.906],
#     'Demanda (GWh) - Mayor': [23.518, 24.272, 26.380, 28.609, 30.782, 32.916, 35.188, 40.074, 45.395, 50.854],
# }

# df_energia_hipotesis5 = pd.DataFrame(data)
# df_energia_hipotesis5.set_index('Año', inplace=True)

# # Generación del gráfico de líneas para los tres escenarios de demanda
# plt.figure(figsize=(12, 6))

# # Trazado de las líneas
# plt.plot(df_energia_hipotesis5.index, df_energia_hipotesis5['Demanda (GWh) - Menor'], label='Escenario Menor', marker='s', linestyle='--')
# plt.plot(df_energia_hipotesis5.index, df_energia_hipotesis5['Demanda (GWh) - Medio'], label='Escenario Medio', marker='o', linestyle='-')
# plt.plot(df_energia_hipotesis5.index, df_energia_hipotesis5['Demanda (GWh) - Mayor'], label='Escenario Mayor', marker='^', linestyle='-.')

# # Añadir título y etiquetas
# plt.title('Previsión de la Demanda Anual de Energía Eléctrica (Hipótesis No. 5: 2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda de Energía (GWh)', fontsize=12)

# # Configuración del eje X (mostrar todos los años)
# plt.xticks(df_energia_hipotesis5.index)

# # Añadir leyenda y cuadrícula
# plt.legend(title='Escenario de Previsión')
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Tabla Nro. 3-1: DSVIACIÓN DE DEMANDA DE PORTENCIA Y DENERFIA EN VORENAS DE GERNERACION 2016

# %%
# import pandas as pd

# # Datos extraídos de la tabla
# data = {
#     'Variable': ['Potencia Máxima Coincidente', 'Energía'],
#     'Unidad': ['MW', 'GWh'],
#     'Proyección': [3683, 22484],
#     'Demanda Real': [3653, 23518],
#     'Desviación (%)': [0.83, 4.60]
# }

# # Creación del DataFrame
# df_desviacion_2016 = pd.DataFrame(data)

# # Mostrar el DataFrame
# print("DataFrame de Desviación de Demanda de Potencia y Energía (2016):")
# print(df_desviacion_2016)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # DataFrame del Paso 3 (usando los datos de Desviación)
# data = {
#     'Variable': ['Potencia Máxima Coincidente', 'Energía'],
#     'Unidad': ['MW', 'GWh'],
#     'Proyección': [3683, 22484],
#     'Demanda Real': [3653, 23518],
#     'Desviación (%)': [0.83, 4.60]
# }
# df_desviacion_2016 = pd.DataFrame(data)
# df_desviacion_2016.set_index('Variable', inplace=True)

# # Generación del gráfico de barras para la Desviación
# plt.figure(figsize=(8, 5))

# # Creación del gráfico de barras para Desviación (%)
# bars = plt.bar(df_desviacion_2016.index, df_desviacion_2016['Desviación (%)'], color=['lightcoral', 'skyblue'])

# # Añadir título y etiquetas
# plt.title('Desviación Porcentual de la Demanda (Proyección vs. Real) - Año 2016', fontsize=14)
# plt.xlabel('Variable', fontsize=12)
# plt.ylabel('Desviación (%)', fontsize=12)

# # Añadir el valor de la barra en la parte superior
# for bar in bars:
#     yval = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width()/2, yval + 0.1, f'{yval:.2f}%', ha='center', va='bottom')

# # Limitar el eje Y
# plt.ylim(0, 5.5)

# # Añadir una cuadrícula
# plt.grid(axis='y', linestyle='--', alpha=0.7)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# TABLÑA 3_2: Variación mensual de la demanda de potencia

# %%
# import pandas as pd

# # Datos extraídos de la tabla
# data = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
#             'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#     'Potencia (MW) - 2015': [3504, 3523, 3540, 3607, 3602, 3560, 3525, 3471, 3545, 3591, 3653, 3670],
#     'Potencia (MW) - 2016': [3593, 3638, 3653, 3583, 3587, 3471, 3450, 3450, 3490, 3457, 3573, 3625],
#     'Variación (%)': [2.54, 3.26, 3.17, -0.66, -0.42, -2.50, -2.12, -0.60, -1.53, -3.72, -2.20, -1.22]
# }

# # Creación del DataFrame
# df_potencia_mensual = pd.DataFrame(data)

# # Establecer el Mes como índice
# df_potencia_mensual.set_index('Mes', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Potencia Máxima Mensual S.N.I. (MW) 2015 vs 2016:")
# print(df_potencia_mensual)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # DataFrame del Paso 3
# data = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
#             'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#     'Potencia (MW) - 2015': [3504, 3523, 3540, 3607, 3602, 3560, 3525, 3471, 3545, 3591, 3653, 3670],
#     'Potencia (MW) - 2016': [3593, 3638, 3653, 3583, 3587, 3471, 3450, 3450, 3490, 3457, 3573, 3625],
#     'Variación (%)': [2.54, 3.26, 3.17, -0.66, -0.42, -2.50, -2.12, -0.60, -1.53, -3.72, -2.20, -1.22]
# }
# df_potencia_mensual = pd.DataFrame(data)
# df_potencia_mensual.set_index('Mes', inplace=True)


# # Generación del gráfico de líneas
# plt.figure(figsize=(12, 6))

# # Trazado de las dos series de potencia
# plt.plot(df_potencia_mensual.index, df_potencia_mensual['Potencia (MW) - 2015'],
#          label='2015', marker='o', linestyle='-', color='goldenrod')
# plt.plot(df_potencia_mensual.index, df_potencia_mensual['Potencia (MW) - 2016'],
#          label='2016', marker='s', linestyle='--', color='darkblue')

# # Añadir título y etiquetas
# plt.title('Potencia Máxima Mensual S.N.I. (MW) - Comparación 2015 vs 2016', fontsize=14)
# plt.xlabel('Mes', fontsize=12)
# plt.ylabel('Potencia Máxima (MW)', fontsize=12)

# # Rotar etiquetas del eje X para mejor legibilidad
# plt.xticks(rotation=45, ha='right')

# # Añadir leyenda y cuadrícula
# plt.legend(title='Año')
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# TABLÑA 3_3: Variación mensual de la demanda de LA ENERGÍA  del S.N.I. para 2015 y 2016 (MW y GWh)

# %%
# import pandas as pd

# # Datos extraídos de la tabla (multiplicados por 1000 para trabajar con valores enteros en GWh)
# data = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
#             'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#     # Convertimos los valores GWh a un formato numérico adecuado
#     'Energía (GWh) - 2015': [1859, 1719, 1933, 1872, 1976, 1892, 1931, 1839, 1777, 1863, 1862, 1957],
#     'Energía (GWh) - 2016': [1991, 1884, 2167, 1941, 1834, 1974, 1948, 1973, 1917, 1947, 1908, 2032],
#     'Variación (%)': [7.09, 9.57, 12.14, 3.71, -7.17, 4.34, 0.89, 7.28, 7.85, 4.55, 2.49, 3.85]
# }

# # Creación del DataFrame
# df_energia_mensual = pd.DataFrame(data)

# # Establecer el Mes como índice
# df_energia_mensual.set_index('Mes', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Energía Mensual S.N.I. (GWh) 2015 vs 2016:")
# print(df_energia_mensual)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # DataFrame del Paso 3
# data = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
#             'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#     'Energía (GWh) - 2015': [1859, 1719, 1933, 1872, 1976, 1892, 1931, 1839, 1777, 1863, 1862, 1957],
#     'Energía (GWh) - 2016': [1991, 1884, 2167, 1941, 1834, 1974, 1948, 1973, 1917, 1947, 1908, 2032],
#     'Variación (%)': [7.09, 9.57, 12.14, 3.71, -7.17, 4.34, 0.89, 7.28, 7.85, 4.55, 2.49, 3.85]
# }
# df_energia_mensual = pd.DataFrame(data)
# df_energia_mensual.set_index('Mes', inplace=True)

# # Generación del gráfico de líneas
# plt.figure(figsize=(12, 6))

# # Trazado de las dos series de energía
# plt.plot(df_energia_mensual.index, df_energia_mensual['Energía (GWh) - 2015'],
#          label='2015', marker='o', linestyle='-', color='darkorange')
# plt.plot(df_energia_mensual.index, df_energia_mensual['Energía (GWh) - 2016'],
#          label='2016', marker='s', linestyle='--', color='darkgreen')

# # Añadir título y etiquetas
# plt.title('Energía Mensual S.N.I. (GWh) - Comparación 2015 vs 2016', fontsize=14)
# plt.xlabel('Mes', fontsize=12)
# plt.ylabel('Energía Demandada (GWh)', fontsize=12)

# # Rotar etiquetas del eje X para mejor legibilidad
# plt.xticks(rotation=45, ha='right')

# # Añadir leyenda y cuadrícula
# plt.legend(title='Año')
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Tasa de crecimiento del PIB 2007-2016 (Tabla Nro. 3-4).

# %%
# import pandas as pd

# # Datos extraídos de la tabla
# data = {
#     'Año': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#     'Tasa de Crecimiento del PIB (%)': [2.2, 6.4, 0.6, 3.5, 7.9, 5.6, 4.9, 4.0, 0.25, -1.6]
# }

# # Creación del DataFrame
# df_pib = pd.DataFrame(data)

# # Establecer el Año como índice
# df_pib.set_index('Año', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Tasa de Crecimiento del PIB (2007-2016):")
# print(df_pib)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # DataFrame del Paso 3
# data = {
#     'Año': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#     'Tasa de Crecimiento del PIB (%)': [2.2, 6.4, 0.6, 3.5, 7.9, 5.6, 4.9, 4.0, 0.25, -1.6]
# }
# df_pib = pd.DataFrame(data)
# df_pib.set_index('Año', inplace=True)

# # Generación del gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Trazado de la serie
# plt.plot(df_pib.index, df_pib['Tasa de Crecimiento del PIB (%)'],
#          label='Tasa de Crecimiento', marker='o', linestyle='-', color='teal')

# # Añadir una línea de referencia en 0% (cero crecimiento)
# plt.axhline(0, color='red', linestyle='--', linewidth=0.8, label='Crecimiento Cero')

# # Añadir título y etiquetas
# plt.title('Tasa de Crecimiento del PIB (2007-2016)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Crecimiento del PIB (%)', fontsize=12)

# # Configuración del eje X (mostrar todos los años)
# plt.xticks(df_pib.index)

# # Añadir leyenda y cuadrícula
# plt.legend()
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Energía Eléctrica (GWh) en barras de subestaciones de entrega para la Hipótesis No. 3, cubriendo el período de 2016 a 2025.

# %%
# import pandas as pd

# # Datos extraídos de la tabla para la Demanda de Energía (GWh)
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [21594, 22681, 23972, 25161, 26269, 27325, 28292, 29347, 30301, 31458],
#     'Demanda (GWh) - Medio': [21594, 22923, 24476, 25927, 27328, 28692, 30008, 31436, 32787, 34366],
#     'Demanda (GWh) - Mayor': [21594, 23137, 24923, 26631, 28311, 29984, 31643, 33443, 35198, 37217],
#     # Incluimos la tasa de crecimiento medio para referencia
#     'Crecimiento (%) - Medio': [0.0, 6.2, 6.8, 5.9, 5.4, 5.0, 4.6, 4.8, 4.3, 4.8]
# }

# # Creación del DataFrame
# df_prevision_energia = pd.DataFrame(data)

# # Establecer el Año como índice
# df_prevision_energia.set_index('Año', inplace=True)

# # Mostrar el DataFrame
# print("DataFrame de Previsión de la Demanda Anual de Energía Eléctrica (GWh) - Hipótesis 3:")
# print(df_prevision_energia)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # DataFrame del Paso 3
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [21594, 22681, 23972, 25161, 26269, 27325, 28292, 29347, 30301, 31458],
#     'Demanda (GWh) - Medio': [21594, 22923, 24476, 25927, 27328, 28692, 30008, 31436, 32787, 34366],
#     'Demanda (GWh) - Mayor': [21594, 23137, 24923, 26631, 28311, 29984, 31643, 33443, 35198, 37217],
# }
# df_prevision_energia = pd.DataFrame(data)
# df_prevision_energia.set_index('Año', inplace=True)

# # Generación del gráfico de líneas
# plt.figure(figsize=(12, 6))

# # Trazado de las tres series
# plt.plot(df_prevision_energia.index, df_prevision_energia['Demanda (GWh) - Menor'],
#          label='Escenario Menor', marker='o', linestyle='--')
# plt.plot(df_prevision_energia.index, df_prevision_energia['Demanda (GWh) - Medio'],
#          label='Escenario Medio', marker='s', linestyle='-')
# plt.plot(df_prevision_energia.index, df_prevision_energia['Demanda (GWh) - Mayor'],
#          label='Escenario Mayor', marker='^', linestyle='-.')

# # Añadir título y etiquetas
# plt.title('Previsión de la Demanda Anual de Energía Eléctrica (GWh) - Hipótesis No. 3 (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda de Energía (GWh)', fontsize=12)

# # Configuración del eje X (mostrar todos los años)
# plt.xticks(df_prevision_energia.index)

# # Añadir leyenda y cuadrícula
# plt.legend(title='Escenario de Previsión')
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Potencia en Bornes de Generación y Barras de Subestación del SNI - Hipótesis No. 3

# %%
# import pandas as pd

# # Datos de Demanda extraídos de la tabla de "Demanda de Potencia (GWh)"
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [3.532, 3.707, 3.907, 4.112, 4.262, 4.404, 4.537, 4.679, 4.810, 4.851],
#     'Demanda (GWh) - Medio': [3.532, 3.746, 3.989, 4.236, 4.432, 4.622, 4.809, 5.008, 5.198, 5.296],
#     'Demanda (GWh) - Mayor': [3.532, 3.778, 4.056, 4.341, 4.578, 4.812, 5.047, 5.298, 5.545, 5.701]
# }

# # Datos de Crecimiento Anual Compuesto (Crec. 2016-2025)
# crecimiento_anual = {
#     'Menor': '3.59%',
#     'Medio': '4.60%',
#     'Mayor': '5.46%'
# }

# df = pd.DataFrame(data)

# # Establecer el 'Año' como índice para facilitar la graficación
# df.set_index('Año', inplace=True)

# print("DataFrame de Demanda de Potencia (GWh):")
# print(df)
# print("\nCrecimiento Anual Compuesto (2016-2025):")
# print(crecimiento_anual)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos de la tabla de "Demanda de Potencia (GWh)"
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [3.532, 3.707, 3.907, 4.112, 4.262, 4.404, 4.537, 4.679, 4.810, 4.851],
#     'Demanda (GWh) - Medio': [3.532, 3.746, 3.989, 4.236, 4.432, 4.622, 4.809, 5.008, 5.198, 5.296],
#     'Demanda (GWh) - Mayor': [3.532, 3.778, 4.056, 4.341, 4.578, 4.812, 5.047, 5.298, 5.545, 5.701]
# }

# df = pd.DataFrame(data)
# df.set_index('Año', inplace=True)

# # Generación del gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Se usa un bucle para graficar cada columna (hipótesis)
# for column in df.columns:
#     plt.plot(df.index, df[column], marker='o', label=column.replace('Demanda (GWh) - ', ''))

# plt.title('Proyección de la Demanda Anual de Potencia (2016-2025)')
# plt.xlabel('Año')
# plt.ylabel('Demanda (GWh)')
# plt.legend(title='Hipótesis de Crecimiento')
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.xticks(df.index) # Asegura que todos los años aparezcan en el eje X
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Energía Eléctrica en Bornes de Generación del SNI - Hipótesis No. 3.

# %%
# import pandas as pd

# # Datos de la demanda de energía (GWh) extraídos de la tabla
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
#     'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
#     'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861]
# }
# data_crecimiento = {
#     'Hipótesis': ['Menor', 'Medio', 'Mayor'],
#     'Crecimiento Anual Compuesto (%)': [4.48, 5.45, 6.33]
# }
# df_demanda = pd.DataFrame(data)
# df_demanda = df_demanda.set_index('Año')

# # Mostrar el DataFrame (opcional, para verificación)
# print(df_demanda)
# print(data_crecimiento)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos de la demanda de energía (GWh) extraídos de la tabla
# data = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
#     'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
#     'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861]
# }

# df_demanda = pd.DataFrame(data)
# df_demanda = df_demanda.set_index('Año')

# # Generar el gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Usamos la función plot() de Pandas/Matplotlib para graficar las tres series
# df_demanda.plot(kind='line', ax=plt.gca(), marker='o')

# # Configuración del gráfico
# plt.title('Sensibilidad de la Proyección de la Demanda de Energía (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda (GWh)', fontsize=12)
# plt.xticks(df_demanda.index) # Asegura que todos los años estén en el eje X
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Hipótesis de Crecimiento')
# plt.tight_layout() # Ajusta el diseño para evitar superposiciones
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Potencia Eléctrica en Bornes de Generación del SNI - Hipótesis No. 3.

# %%
# import pandas as pd

# # DataFrame 1: Datos de la Demanda de Potencia (MW)
# data_demanda_potencia = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3.653, 3.947, 4.205, 4.456, 4.663, 4.865, 5.074, 5.240, 5.372, 5.409],
#     'Demanda (MW) - Medio': [3.653, 3.987, 4.290, 4.585, 4.839, 5.091, 5.355, 5.579, 5.773, 5.868],
#     'Demanda (MW) - Mayor': [3.653, 4.020, 4.359, 4.693, 4.989, 5.286, 5.601, 5.878, 6.130, 6.285]
# }

# df_potencia = pd.DataFrame(data_demanda_potencia)
# df_potencia = df_potencia.set_index('Año')

# # DataFrame 2: Porcentaje de Crecimiento Anual Compuesto (2016-2025) - Incluido para completitud
# data_crecimiento_potencia = {
#     'Hipótesis': ['Menor', 'Medio', 'Mayor'],
#     'Crecimiento Anual Compuesto (%)': [4.46, 5.41, 6.22]
# }

# df_crecimiento_potencia = pd.DataFrame(data_crecimiento_potencia)

# # print(df_potencia)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # DataFrame 1: Datos de la Demanda de Potencia (MW)
# data_demanda_potencia = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3.653, 3.947, 4.205, 4.456, 4.663, 4.865, 5.074, 5.240, 5.372, 5.409],
#     'Demanda (MW) - Medio': [3.653, 3.987, 4.290, 4.585, 4.839, 5.091, 5.355, 5.579, 5.773, 5.868],
#     'Demanda (MW) - Mayor': [3.653, 4.020, 4.359, 4.693, 4.989, 5.286, 5.601, 5.878, 6.130, 6.285]
# }

# df_potencia = pd.DataFrame(data_demanda_potencia)
# df_potencia = df_potencia.set_index('Año')


# # Generar el gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Se renombra temporalmente las columnas para la leyenda del gráfico (quitando la unidad MW)
# df_plot = df_potencia.rename(columns={
#     'Demanda (MW) - Menor': 'Menor',
#     'Demanda (MW) - Medio': 'Medio',
#     'Demanda (MW) - Mayor': 'Mayor'
# })

# # Se utilizan marcadores y colores similares a la imagen original
# df_plot['Menor'].plot(kind='line', ax=plt.gca(), marker='o', color='#7ac143')
# df_plot['Medio'].plot(kind='line', ax=plt.gca(), marker='s', color='#1d71b8')
# df_plot['Mayor'].plot(kind='line', ax=plt.gca(), marker='o', color='#e53e50')


# # Configuración del gráfico
# plt.title('Sensibilidad de la Proyección de la Demanda de Potencia (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda (MW)', fontsize=12)
# plt.xticks(df_potencia.index)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Hipótesis de Crecimiento', loc='lower center', ncol=3)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Energía Eléctrica en Barras de Subestaciones de Entrega del SNI - Hipótesis No. 5.

# %%
# import pandas as pd

# # DataFrame 1: Datos de la Demanda de Energía (GWh)
# data_demanda_subestacion = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [21.594, 22.690, 23.984, 25.179, 26.318, 27.383, 28.449, 29.537, 30.491, 31.647],
#     'Demanda (GWh) - Medio': [21.594, 22.932, 24.488, 25.945, 27.377, 28.751, 30.165, 31.626, 32.976, 34.555],
#     'Demanda (GWh) - Mayor': [21.594, 23.146, 24.936, 26.648, 28.360, 30.043, 31.800, 33.632, 35.387, 37.406]
# }

# df_demanda = pd.DataFrame(data_demanda_subestacion)
# df_demanda = df_demanda.set_index('Año')

# # DataFrame 2: Porcentaje de Crecimiento Anual Compuesto (2016-2025)
# data_crecimiento_subestacion = {
#     'Hipótesis': ['Menor', 'Medio', 'Mayor'],
#     'Crecimiento Anual Compuesto (%)': [4.34, 5.36, 6.29]
# }

# df_crecimiento = pd.DataFrame(data_crecimiento_subestacion)

# print(df_demanda)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # DataFrame con los datos de la demanda (GWh)
# data_demanda_subestacion = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [21.594, 22.690, 23.984, 25.179, 26.318, 27.383, 28.449, 29.537, 30.491, 31.647],
#     'Demanda (GWh) - Medio': [21.594, 22.932, 24.488, 25.945, 27.377, 28.751, 30.165, 31.626, 32.976, 34.555],
#     'Demanda (GWh) - Mayor': [21.594, 23.146, 24.936, 26.648, 28.360, 30.043, 31.800, 33.632, 35.387, 37.406]
# }

# df_demanda = pd.DataFrame(data_demanda_subestacion)
# df_demanda = df_demanda.set_index('Año')

# # Generar el gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Se renombra temporalmente las columnas para la leyenda del gráfico
# df_plot = df_demanda.rename(columns={
#     'Demanda (GWh) - Menor': 'Menor',
#     'Demanda (GWh) - Medio': 'Medio',
#     'Demanda (GWh) - Mayor': 'Mayor'
# })

# # Plotting con estilos similares a la imagen original
# df_plot['Menor'].plot(kind='line', ax=plt.gca(), marker='D', color='#7ac143')
# df_plot['Medio'].plot(kind='line', ax=plt.gca(), marker='s', color='#1d71b8')
# df_plot['Mayor'].plot(kind='line', ax=plt.gca(), marker='o', color='#e53e50')


# # Configuración del gráfico
# plt.title('Sensibilidad de la Proyección de la Demanda de Energía en Barras de Subestación (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda (GWh)', fontsize=12)
# plt.xticks(df_demanda.index)
# # Ajuste del eje Y para que coincida con el rango de la gráfica original (20.000 a 40.000)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Hipótesis de Crecimiento', loc='lower center', ncol=3)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Potencia Eléctrica en Barras de Subestaciones de Entrega del SNI - Hipótesis No. 5.

# %%
# import pandas as pd

# # DataFrame 1: Datos de la Demanda de Potencia (MW)
# data_demanda_potencia_subestacion = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3.532, 3.708, 3.909, 4.114, 4.268, 4.411, 4.555, 4.701, 4.832, 4.873],
#     'Demanda (MW) - Medio': [3.532, 3.747, 3.990, 4.238, 4.438, 4.629, 4.827, 5.029, 5.220, 5.318],
#     'Demanda (MW) - Mayor': [3.532, 3.779, 4.057, 4.344, 4.584, 4.819, 5.065, 5.320, 5.566, 5.722]
# }

# df_potencia_subestacion = pd.DataFrame(data_demanda_potencia_subestacion)
# df_potencia_subestacion = df_potencia_subestacion.set_index('Año')

# # DataFrame 2: Porcentaje de Crecimiento Anual Compuesto (2016-2025)
# data_crecimiento_potencia = {
#     'Hipótesis': ['Menor', 'Medio', 'Mayor'],
#     'Crecimiento Anual Compuesto (%)': [3.64, 4.65, 5.51]
# }

# df_crecimiento_potencia = pd.DataFrame(data_crecimiento_potencia)

# print(df_potencia_subestacion)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # DataFrame con los datos de la demanda (MW)
# data_demanda_potencia_subestacion = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3.532, 3.708, 3.909, 4.114, 4.268, 4.411, 4.555, 4.701, 4.832, 4.873],
#     'Demanda (MW) - Medio': [3.532, 3.747, 3.990, 4.238, 4.438, 4.629, 4.827, 5.029, 5.220, 5.318],
#     'Demanda (MW) - Mayor': [3.532, 3.779, 4.057, 4.344, 4.584, 4.819, 5.065, 5.320, 5.566, 5.722]
# }

# df_potencia_subestacion = pd.DataFrame(data_demanda_potencia_subestacion)
# df_potencia_subestacion = df_potencia_subestacion.set_index('Año')

# # Generar el gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Se renombra temporalmente las columnas para la leyenda del gráfico
# df_plot = df_potencia_subestacion.rename(columns={
#     'Demanda (MW) - Menor': 'Menor',
#     'Demanda (MW) - Medio': 'Medio',
#     'Demanda (MW) - Mayor': 'Mayor'
# })

# # Plotting con estilos similares a la imagen original
# df_plot['Menor'].plot(kind='line', ax=plt.gca(), marker='o', color='#7ac143')
# df_plot['Medio'].plot(kind='line', ax=plt.gca(), marker='s', color='#1d71b8')
# df_plot['Mayor'].plot(kind='line', ax=plt.gca(), marker='o', color='#e53e50')


# # Configuración del gráfico
# plt.title('Sensibilidad de la Proyección de la Demanda de Potencia en Barras de Subestación (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('MW', fontsize=12) # Etiqueta Y según la gráfica
# plt.xticks(df_potencia_subestacion.index)
# # Ajuste del eje Y para que coincida con el rango de la gráfica original (3.000 a 7.000)
# plt.yticks(np.arange(3.000, 7.000 + 1.000, 1.000))
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Hipótesis de Crecimiento', loc='lower center', ncol=3)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Energía Eléctrica en Bornes de Generación.

# %%
# import pandas as pd

# # DataFrame 1: Datos de la Demanda de Energía (GWh)
# data_demanda_bornes = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.800, 25.395, 27.088, 28.669, 30.164, 31.721, 35.837, 40.329, 44.898],
#     'Demanda (GWh) - Medio': [23.518, 24.050, 25.917, 27.881, 29.765, 31.579, 33.497, 37.999, 42.901, 47.906],
#     'Demanda (GWh) - Mayor': [23.518, 24.272, 26.380, 28.609, 30.782, 32.916, 35.188, 40.074, 45.395, 50.854]
# }

# df_demanda = pd.DataFrame(data_demanda_bornes)
# df_demanda = df_demanda.set_index('Año')

# # DataFrame 2: Porcentaje de Crecimiento Anual Compuesto (2016-2025) - (Opcional, para referencia)
# data_crecimiento = {
#     'Hipótesis': ['Menor', 'Medio', 'Mayor'],
#     'Crecimiento Anual Compuesto (%)': [7.45, 8.23, 8.95]
# }

# df_crecimiento = pd.DataFrame(data_crecimiento)

# print(df_demanda)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # DataFrame con los datos de la demanda (GWh)
# data_demanda_bornes = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (GWh) - Menor': [23.518, 23.800, 25.395, 27.088, 28.669, 30.164, 31.721, 35.837, 40.329, 44.898],
#     'Demanda (GWh) - Medio': [23.518, 24.050, 25.917, 27.881, 29.765, 31.579, 33.497, 37.999, 42.901, 47.906],
#     'Demanda (GWh) - Mayor': [23.518, 24.272, 26.380, 28.609, 30.782, 32.916, 35.188, 40.074, 45.395, 50.854]
# }

# df_demanda = pd.DataFrame(data_demanda_bornes)
# df_demanda = df_demanda.set_index('Año')

# # Generar el gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Se renombra temporalmente las columnas para la leyenda del gráfico
# df_plot = df_demanda.rename(columns={
#     'Demanda (GWh) - Menor': 'Menor',
#     'Demanda (GWh) - Medio': 'Medio',
#     'Demanda (GWh) - Mayor': 'Mayor'
# })

# # Plotting con estilos similares a la imagen original
# df_plot['Menor'].plot(kind='line', ax=plt.gca(), marker='D', color='#7ac143')
# df_plot['Medio'].plot(kind='line', ax=plt.gca(), marker='s', color='#1d71b8')
# df_plot['Mayor'].plot(kind='line', ax=plt.gca(), marker='o', color='#e53e50')


# # Configuración del gráfico
# plt.title('Sensibilidad de la Proyección de la Demanda de Energía en Bornes de Generación (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('GWh', fontsize=12) # Etiqueta Y según la gráfica
# plt.xticks(df_demanda.index)
# # Ajuste del eje Y para que coincida con el rango de la gráfica original (20.000 a 55.000)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Hipótesis de Crecimiento', loc='lower center', ncol=3)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Potencia Eléctrica en Bornes de Generación del SNI - Hipótesis No. 5. 3_36

# %%
# import pandas as pd

# # DataFrame 1: Datos de la Demanda de Potencia (MW)
# data_demanda_potencia_bornes = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3.653, 3.948, 4.211, 4.481, 4.691, 4.895, 5.115, 5.724, 6.252, 6.684],
#     'Demanda (MW) - Medio': [3.653, 3.988, 4.295, 4.610, 4.867, 5.120, 5.396, 6.064, 6.653, 7.144],
#     'Demanda (MW) - Mayor': [3.653, 4.022, 4.364, 4.718, 5.017, 5.316, 5.642, 6.363, 7.010, 7.560]
# }

# df_potencia = pd.DataFrame(data_demanda_potencia_bornes)
# df_potencia = df_potencia.set_index('Año')

# # DataFrame 2: Porcentaje de Crecimiento Anual Compuesto (2016-2025) - (Opcional, para referencia)
# data_crecimiento = {
#     'Hipótesis': ['Menor', 'Medio', 'Mayor'],
#     'Crecimiento Anual Compuesto (%)': [6.95, 7.74, 8.42]
# }

# df_crecimiento = pd.DataFrame(data_crecimiento)

# print(df_potencia)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # DataFrame con los datos de la demanda (MW)
# data_demanda_potencia_bornes = {
#     'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#     'Demanda (MW) - Menor': [3.653, 3.948, 4.211, 4.481, 4.691, 4.895, 5.115, 5.724, 6.252, 6.684],
#     'Demanda (MW) - Medio': [3.653, 3.988, 4.295, 4.610, 4.867, 5.120, 5.396, 6.064, 6.653, 7.144],
#     'Demanda (MW) - Mayor': [3.653, 4.022, 4.364, 4.718, 5.017, 5.316, 5.642, 6.363, 7.010, 7.560]
# }

# df_potencia = pd.DataFrame(data_demanda_potencia_bornes)
# df_potencia = df_potencia.set_index('Año')

# # Generar el gráfico de líneas
# plt.figure(figsize=(10, 6))

# # Se renombra temporalmente las columnas para la leyenda del gráfico
# df_plot = df_potencia.rename(columns={
#     'Demanda (MW) - Menor': 'Menor',
#     'Demanda (MW) - Medio': 'Medio',
#     'Demanda (MW) - Mayor': 'Mayor'
# })

# # Plotting con estilos similares a la imagen original
# df_plot['Menor'].plot(kind='line', ax=plt.gca(), marker='D', color='#7ac143')
# df_plot['Medio'].plot(kind='line', ax=plt.gca(), marker='s', color='#1d71b8')
# df_plot['Mayor'].plot(kind='line', ax=plt.gca(), marker='o', color='#e53e50')


# # Configuración del gráfico
# plt.title('Sensibilidad de la Proyección de la Demanda de Potencia en Bornes de Generación (2016-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('MW', fontsize=12) # Etiqueta Y según la gráfica
# plt.xticks(df_potencia.index)
# # Ajuste del eje Y para que coincida con el rango de la gráfica original (3.000 a 9.000)
# plt.yticks(np.arange(3.000, 9.000 + 1.000, 1.000))
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Hipótesis de Crecimiento', loc='lower center', ncol=3)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Previsión de la Demanda Anual de Energía Eléctrica en Barras de Subestaciones de Entrega del S.N.I - Hipótesis No. 3._ 3.6.1

# %%
# import pandas as pd
# import numpy as np

# # Datos combinados de demanda (Histórico 2001-2016 y Proyección Media 2017-2025)
# data_combinada = {
#     'Año': list(range(2001, 2017)) + list(range(2017, 2026)),
#     'Demanda (GWh) - Histórico/Menor': [
#         10.463, 10.899, 11.506, 12.306, 13.057, 13.791, 14.428, 15.260, 15.979, 16.824,
#         17.883, 18.721, 19.538, 20.928, 21.995, 21.555,
#         22.636, 23.923, 25.109, 26.216, 27.270, 28.237, 29.292, 30.245, 31.402
#     ],
#     'Demanda (GWh) - Medio': [
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         22.876, 24.427, 25.874, 27.273, 28.635, 29.951, 31.378, 32.727, 34.306
#     ],
#     'Demanda (GWh) - Mayor': [
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         23.091, 24.873, 26.577, 28.254, 29.926, 31.582, 33.382, 35.135, 37.153
#     ]
# }

# df_demanda = pd.DataFrame(data_combinada)

# # Reemplazar los valores históricos con la columna "Menor" para plotear una sola línea base histórica
# df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Menor'] = df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Histórico/Menor']
# df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Medio'] = df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Histórico/Menor']
# df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Mayor'] = df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Histórico/Menor']

# df_demanda = df_demanda.set_index('Año').drop(columns=['Demanda (GWh) - Histórico/Menor'])

# print(df_demanda.tail())

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # DataFrame con los datos de demanda (se omite la recreación por concisión, usando el df del paso 3)

# # Datos combinados de demanda (Histórico 2001-2016 y Proyección 2017-2025)
# data_combinada = {
#     'Año': list(range(2001, 2017)) + list(range(2017, 2026)),
#     'Demanda (GWh) - Histórico/Menor': [
#         10.463, 10.899, 11.506, 12.306, 13.057, 13.791, 14.428, 15.260, 15.979, 16.824,
#         17.883, 18.721, 19.538, 20.928, 21.995, 21.555,
#         22.636, 23.923, 25.109, 26.216, 27.270, 28.237, 29.292, 30.245, 31.402
#     ],
#     'Demanda (GWh) - Medio': [
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         22.876, 24.427, 25.874, 27.273, 28.635, 29.951, 31.378, 32.727, 34.306
#     ],
#     'Demanda (GWh) - Mayor': [
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
#         23.091, 24.873, 26.577, 28.254, 29.926, 31.582, 33.382, 35.135, 37.153
#     ]
# }

# df_demanda = pd.DataFrame(data_combinada)
# df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Menor'] = df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Histórico/Menor']
# df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Medio'] = df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Histórico/Menor']
# df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Mayor'] = df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (GWh) - Histórico/Menor']

# df_demanda = df_demanda.set_index('Año').drop(columns=['Demanda (GWh) - Histórico/Menor'])


# # Generar el gráfico de líneas
# plt.figure(figsize=(12, 6))

# # Se renombra temporalmente las columnas para la leyenda del gráfico
# df_plot = df_demanda.rename(columns={
#     'Demanda (GWh) - Menor': 'Menor',
#     'Demanda (GWh) - Medio': 'Medio',
#     'Demanda (GWh) - Mayor': 'Mayor'
# })

# # Plotting
# df_plot['Menor'].plot(kind='line', ax=plt.gca(), label='Menor (Incluye Histórico)', color='green', linestyle='-')
# df_plot['Medio'].plot(kind='line', ax=plt.gca(), label='Medio', color='blue', linestyle='--') # Se usa línea discontinua para diferenciar proyección
# df_plot['Mayor'].plot(kind='line', ax=plt.gca(), label='Mayor', color='red', linestyle='--')

# # Configuración del gráfico
# plt.title('Demanda Anual de Energía Eléctrica (GWh) - Histórico (2001-2016) y Proyección (2017-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda de Energía (GWh)', fontsize=12)

# # Mostrar solo los años clave y los de proyección en el eje X
# x_ticks = list(range(2001, 2026, 2))
# if 2025 not in x_ticks: x_ticks.append(2025)
# plt.xticks(x_ticks, rotation=45)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Hipótesis de Demanda', loc='upper left')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ANEXO 3.2 PREVISIÓN DE LA DEMANDA ANUAL DE POTENCIA ELÉCTRICA EN BARRAS DE SUBESTACIONES DE ENTREGA DEL S.N.I -

# %%
import pandas as pd
import numpy as np

# Datos combinados de demanda (Histórico 2001-2016 y Proyección 2017-2025)
data_combinada = {
    'Año': list(range(2001, 2017)) + list(range(2017, 2026)),
    'Demanda (MW) - Histórico/Proyección': [
        1.976, 2.136, 2.264, 2.436, 2.519, 2.648, 2.630, 2.728, 2.792, 2.977,
        3.112, 3.196, 3.240, 3.484, 3.646, 3.532, # Valores Históricos hasta 2016
        3.694, 3.894, 4.098, 4.248, 4.390, 4.522, 4.664, 4.795, 4.836 # Proyección Menor
    ],
    'Demanda (MW) - Medio': [
        np.nan] * 16 + [3.744, 3.986, 4.232, 4.427, 4.615, 4.800, 4.997, 5.186, 5.282
    ],
    'Demanda (MW) - Mayor': [
        np.nan] * 16 + [3.765, 4.042, 4.327, 4.563, 4.796, 5.031, 5.282, 5.528, 5.684
    ]
}

df_demanda = pd.DataFrame(data_combinada)

# Usar el valor histórico para las tres series hasta 2016
historico_values = df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (MW) - Histórico/Proyección']
df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (MW) - Menor'] = historico_values
df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (MW) - Medio'] = historico_values
df_demanda.loc[df_demanda['Año'] <= 2016, 'Demanda (MW) - Mayor'] = historico_values

# Eliminar la columna auxiliar y establecer el índice
df_demanda = df_demanda.set_index('Año').drop(columns=['Demanda (MW) - Histórico/Proyección'])

# print(df_demanda.tail())

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# DataFrame con los datos de demanda (MW)
# Recreación del DataFrame df_demanda del paso 3 para asegurar la independencia del bloque de código.
data_combinada = {
    'Año': list(range(2001, 2017)) + list(range(2017, 2026)),
    'Histórico': [1.976, 2.136, 2.264, 2.436, 2.519, 2.648, 2.630, 2.728, 2.792, 2.977, 3.112, 3.196, 3.240, 3.484, 3.646, 3.532] + [np.nan] * 9,
    'Menor': [np.nan] * 16 + [3.694, 3.894, 4.098, 4.248, 4.390, 4.522, 4.664, 4.795, 4.836],
    'Medio': [np.nan] * 16 + [3.744, 3.986, 4.232, 4.427, 4.615, 4.800, 4.997, 5.186, 5.282],
    'Mayor': [np.nan] * 16 + [3.765, 4.042, 4.327, 4.563, 4.796, 5.031, 5.282, 5.528, 5.684]
}

df_demanda = pd.DataFrame(data_combinada).set_index('Año')

# Usar el histórico para la base de todas las proyecciones
historico_indices = df_demanda.index[df_demanda.index <= 2016]
df_demanda.loc[historico_indices, ['Menor', 'Medio', 'Mayor']] = df_demanda.loc[historico_indices, 'Histórico'].values[:, np.newaxis]
df_demanda = df_demanda.drop(columns=['Histórico'])


# Generar el gráfico de líneas
plt.figure(figsize=(12, 6))

# Se renombra las columnas para el plot
df_plot = df_demanda.rename(columns={
    'Menor': 'Menor',
    'Medio': 'Medio',
    'Mayor': 'Mayor'
})

# Plotting
df_plot['Menor'].plot(kind='line', ax=plt.gca(), label='Menor (Incluye Histórico)', color='green', marker='o', markersize=3)
df_plot['Medio'].plot(kind='line', ax=plt.gca(), label='Medio', color='blue', marker='o', markersize=3)
df_plot['Mayor'].plot(kind='line', ax=plt.gca(), label='Mayor', color='red', marker='o', markersize=3)

# Configuración del gráfico
plt.title('Demanda Anual de Potencia Eléctrica (MW) - Histórico (2001-2016) y Proyección (2017-2025)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Demanda de Potencia (MW)', fontsize=12)

# Mostrar solo los años clave y los de proyección en el eje X
x_ticks = list(range(2001, 2026, 2))
if 2025 not in x_ticks: x_ticks.append(2025)
plt.xticks(x_ticks, rotation=45)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Hipótesis de Demanda', loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# anexo3.3 Previsión de la Demanda Anual de Energía Eléctrica en Bornes de Generación.

# %%
# import pandas as pd
# import numpy as np

# # Datos históricos (2001-2015) y el valor de 2016 (22.355 GWh)
# historico = {
#     'Año': list(range(2001, 2016)) + [2016],
#     'Demanda (GWh)': [10.859, 11.541, 12.115, 12.960, 13.769, 14.689, 15.457, 16.315, 16.877, 17.594, 18.645, 19.547, 20.269, 21.461, 22.481, 22.355]
# }
# df_historico = pd.DataFrame(historico).set_index('Año')

# # Datos de proyección (2016-2025)
# proyeccion = {
#     'Año': list(range(2016, 2026)),
#     'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
#     'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
#     'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861]
# }
# df_proyeccion = pd.DataFrame(proyeccion).set_index('Año')

# # Crear el DataFrame final
# df_final = pd.DataFrame(index=list(range(2001, 2026)))

# # Llenar con datos históricos
# df_final['Demanda (GWh) - Menor'] = df_historico['Demanda (GWh)']
# df_final['Demanda (GWh) - Medio'] = df_historico['Demanda (GWh)']
# df_final['Demanda (GWh) - Mayor'] = df_historico['Demanda (GWh)']

# # Sobrescribir con datos de proyección a partir de 2016
# df_final.update(df_proyeccion)

# # Nota: El valor histórico de 2016 (22.355 GWh) es ligeramente diferente al valor inicial de proyección (23.518 GWh)
# # Se usará el valor de proyección (23.518 GWh) para el inicio de 2016 en las tres series de proyección, tal como se muestra en la tabla 3-31.
# df_final.loc[2016] = [23.518, 23.518, 23.518] # Asegurando el valor de inicio de la proyección
# df_final.loc[2017:] = df_proyeccion.loc[2017:] # Asegurando el resto de la proyección

# print(df_final.tail(15))

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np

# # Recreación del DataFrame df_final del paso 3 para asegurar la independencia del bloque de código.
# historico = {
#     'Año': list(range(2001, 2016)) + [2016],
#     'Demanda (GWh)': [10.859, 11.541, 12.115, 12.960, 13.769, 14.689, 15.457, 16.315, 16.877, 17.594, 18.645, 19.547, 20.269, 21.461, 22.481, 22.355]
# }
# df_historico = pd.DataFrame(historico).set_index('Año')
# proyeccion = {
#     'Año': list(range(2016, 2026)),
#     'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
#     'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
#     'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861]
# }
# df_proyeccion = pd.DataFrame(proyeccion).set_index('Año')

# df_final = pd.DataFrame(index=list(range(2001, 2026)))
# df_final['Menor'] = df_historico['Demanda (GWh)']
# df_final['Medio'] = df_historico['Demanda (GWh)']
# df_final['Mayor'] = df_historico['Demanda (GWh)']
# df_final.loc[2016] = [23.518, 23.518, 23.518]
# df_final.loc[2017:] = df_proyeccion.loc[2017:].rename(columns={'Demanda (GWh) - Menor': 'Menor', 'Demanda (GWh) - Medio': 'Medio', 'Demanda (GWh) - Mayor': 'Mayor'})


# # --- Lógica de Plotting ---
# plt.figure(figsize=(12, 6))

# # Plotting de las series
# # Plot de la serie histórica (solo se necesita una, ya que son iguales)
# plt.plot(df_final.index[df_final.index <= 2016], df_final['Menor'].loc[df_final.index <= 2016],
#          label='Histórico (2001-2016)', color='black', marker='.', linestyle='-')

# # Plot de las proyecciones (a partir de 2016, usando los colores y marcadores de la figura original)
# plt.plot(df_final.index[df_final.index >= 2016], df_final['Menor'].loc[df_final.index >= 2016],
#          label='Menor', color='#7ac143', marker='D', linestyle='-')
# plt.plot(df_final.index[df_final.index >= 2016], df_final['Medio'].loc[df_final.index >= 2016],
#          label='Medio', color='#1d71b8', marker='s', linestyle='-')
# plt.plot(df_final.index[df_final.index >= 2016], df_final['Mayor'].loc[df_final.index >= 2016],
#          label='Mayor', color='#e53e50', marker='o', linestyle='-')

# # Configuración del gráfico
# plt.title('Demanda Anual de Energía Eléctrica en Bornes de Generación (2001-2025)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('GWh', fontsize=12)

# # Ajuste del eje X para mostrar un rango coherente
# plt.xticks(np.arange(2001, 2026, 2))


# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Series de Demanda', loc='upper left', ncol=2)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ANEXO 3.4: Previsión de la Demanda Anual de Potencia Eléctrica en Bornes de Generación del S.N.I. - Hipótesis No. 3

# %%
# import pandas as pd
# import numpy as np

# # Definición de los datos extraídos
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [2.002, 2.132, 2.223, 2.401, 2.424, 2.642, 2.706, 2.785, 2.768, 2.879, 3.052, 3.207, 3.332, 3.503, 3.670, 3.653] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [3.947, 4.205, 4.456, 4.663, 4.865, 5.074, 5.240, 5.372, 5.409]
# demanda_medio = [np.nan] * 16 + [3.956, 4.254, 4.545, 4.796, 5.044, 5.305, 5.525, 5.716, 5.809]
# demanda_mayor = [np.nan] * 16 + [4.020, 4.359, 4.693, 4.989, 5.286, 5.601, 5.878, 6.130, 6.285]

# # Creación del diccionario de datos
# datos_demanda = {
#     'Año': años,
#     'Demanda (MW) - Histórico': demanda_historico,
#     'Demanda (MW) - Menor': demanda_menor,
#     'Demanda (MW) - Medio': demanda_medio,
#     'Demanda (MW) - Mayor': demanda_mayor
# }

# # Creación del DataFrame
# df_demanda = pd.DataFrame(datos_demanda)

# # Mostrar el DataFrame (opcional)
# print("DataFrame de Previsión de Demanda de Potencia:")
# print(df_demanda)

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# # --- Código del Paso 3: Definición del DataFrame ---
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [2.002, 2.132, 2.223, 2.401, 2.424, 2.642, 2.706, 2.785, 2.768, 2.879, 3.052, 3.207, 3.332, 3.503, 3.670, 3.653] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [3.947, 4.205, 4.456, 4.663, 4.865, 5.074, 5.240, 5.372, 5.409]
# demanda_medio = [np.nan] * 16 + [3.956, 4.254, 4.545, 4.796, 5.044, 5.305, 5.525, 5.716, 5.809]
# demanda_mayor = [np.nan] * 16 + [4.020, 4.359, 4.693, 4.989, 5.286, 5.601, 5.878, 6.130, 6.285]

# datos_demanda = {
#     'Año': años,
#     'Demanda (MW) - Histórico': demanda_historico,
#     'Demanda (MW) - Menor': demanda_menor,
#     'Demanda (MW) - Medio': demanda_medio,
#     'Demanda (MW) - Mayor': demanda_mayor
# }

# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda.set_index('Año', inplace=True)
# # --- Fin Código del Paso 3 ---


# # Generación del gráfico de líneas
# plt.figure(figsize=(12, 6))

# # Trazar la serie histórica
# plt.plot(df_demanda.index[:16], df_demanda['Demanda (MW) - Histórico'].dropna(),
#          marker='s', markersize=4, linestyle='-', color='black', label='Histórico (2001-2016)')

# # Unir el último punto histórico (2016) con el inicio de cada previsión (2017)
# ultimo_historico_valor = df_demanda.loc[2016, 'Demanda (MW) - Histórico']
# ultimo_historico_año = 2016

# # Para la serie Menor
# años_menor = [ultimo_historico_año] + df_demanda.index[16:].tolist()
# valores_menor = [ultimo_historico_valor] + df_demanda['Demanda (MW) - Menor'].dropna().tolist()
# plt.plot(años_menor, valores_menor,
#          marker='o', markersize=4, linestyle='--', color='red', label='Menor (Previsión)')

# # Para la serie Medio
# años_medio = [ultimo_historico_año] + df_demanda.index[16:].tolist()
# valores_medio = [ultimo_historico_valor] + df_demanda['Demanda (MW) - Medio'].dropna().tolist()
# plt.plot(años_medio, valores_medio,
#          marker='o', markersize=4, linestyle='-', color='blue', label='Medio (Previsión)')

# # Para la serie Mayor
# años_mayor = [ultimo_historico_año] + df_demanda.index[16:].tolist()
# valores_mayor = [ultimo_historico_valor] + df_demanda['Demanda (MW) - Mayor'].dropna().tolist()
# plt.plot(años_mayor, valores_mayor,
#          marker='o', markersize=4, linestyle='-', color='green', label='Mayor (Previsión)')


# # Configuración del gráfico
# plt.title('Previsión de la Demanda Anual de Potencia Eléctrica (MW) 2001-2025')
# plt.xlabel('Año')
# plt.ylabel('Demanda (MW)')
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.legend(title='Escenario de Crecimiento')

# # Ajustar las etiquetas del eje X para mejor lectura
# plt.xticks(df_demanda.index[::2], rotation=45)
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# ANEXO 3.8) sobre la Previsión de la Demanda Anual de Energía Eléctrica

# %%
# import pandas as pd
# import numpy as np

# # Definición de los datos extraídos
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [10.463, 10.899, 11.506, 12.306, 13.057, 13.791, 14.428, 15.260, 15.979, 16.824, 17.883, 18.721, 19.538, 20.928, 21.995, 21.555] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [22.645, 23.935, 25.127, 26.264, 27.329, 28.389, 29.476, 30.429, 31.586]
# demanda_medio = [np.nan] * 16 + [22.886, 24.439, 25.892, 27.322, 28.694, 30.103, 31.561, 32.911, 34.489]
# demanda_mayor = [np.nan] * 16 + [23.100, 24.886, 26.594, 28.303, 29.984, 31.735, 33.565, 35.319, 37.336]

# # Creación del diccionario de datos
# datos_demanda = {
#     'Año': años,
#     'Demanda (GWh) - Histórico': demanda_historico,
#     'Demanda (GWh) - Menor': demanda_menor,
#     'Demanda (GWh) - Medio': demanda_medio,
#     'Demanda (GWh) - Mayor': demanda_mayor
# }

# # Creación del DataFrame
# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce') # Asegura que los tipos sean numéricos

# print("DataFrame de Previsión de Demanda de Energía:")
# print(df_demanda)

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# # --- Código del Paso 3: Definición del DataFrame ---
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [10.463, 10.899, 11.506, 12.306, 13.057, 13.791, 14.428, 15.260, 15.979, 16.824, 17.883, 18.721, 19.538, 20.928, 21.995, 21.555] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [22.645, 23.935, 25.127, 26.264, 27.329, 28.389, 29.476, 30.429, 31.586]
# demanda_medio = [np.nan] * 16 + [22.886, 24.439, 25.892, 27.322, 28.694, 30.103, 31.561, 32.911, 34.489]
# demanda_mayor = [np.nan] * 16 + [23.100, 24.886, 26.594, 28.303, 29.984, 31.735, 33.565, 35.319, 37.336]

# datos_demanda = {
#     'Año': años,
#     'Demanda (GWh) - Histórico': demanda_historico,
#     'Demanda (GWh) - Menor': demanda_menor,
#     'Demanda (GWh) - Medio': demanda_medio,
#     'Demanda (GWh) - Mayor': demanda_mayor
# }

# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce')
# df_demanda.set_index('Año', inplace=True)
# # --- Fin Código del Paso 3 ---


# # --- Corrección de Grieta / Trazado Fluido ---
# plt.figure(figsize=(12, 6))

# # Obtener el último valor histórico para la conexión
# ultimo_historico_valor = df_demanda.loc[2016, 'Demanda (GWh) - Histórico']
# ultimo_historico_año = 2016

# # 1. Trazar la serie histórica (2001-2016)
# plt.plot(df_demanda.index[:16], df_demanda['Demanda (GWh) - Histórico'].dropna(),
#          marker='s', markersize=4, linestyle='-', color='black', label='Histórico (2001-2016)')

# # 2. Trazar las series de previsión, comenzando desde el último punto histórico (2016) para conectar.
# for columna, color, estilo in [('Demanda (GWh) - Menor', 'red', '--'),
#                                ('Demanda (GWh) - Medio', 'blue', '-'),
#                                ('Demanda (GWh) - Mayor', 'green', '-')]:

#     # Prepara los datos para la conexión: [Último Histórico] + [Previsión 2017-2025]
#     años_conexion = [ultimo_historico_año] + df_demanda.index[16:].tolist()
#     valores_prevision = df_demanda[columna].dropna().tolist()
#     valores_conexion = [ultimo_historico_valor] + valores_prevision

#     # Trazar la línea de conexión/previsión
#     plt.plot(años_conexion, valores_conexion,
#              marker='o', markersize=4, linestyle=estilo, color=color,
#              label=columna.split(' - ')[1] + ' (Previsión)')


# # Configuración del gráfico
# plt.title('Previsión de la Demanda Anual de Energía Eléctrica (GWh) 2001-2025')
# plt.xlabel('Año')
# plt.ylabel('Demanda (GWh)')
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.legend(title='Escenario de Crecimiento')

# # Ajustar las etiquetas del eje X para mejor lectura
# plt.xticks(df_demanda.index[::2], rotation=45)
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# ANEXO 3.9) sobre la Previsión de la Demanda Anual de Potencia Eléctrica en Barras de Subestaciones de Entrega del S.N.I.

# %%
# import pandas as pd
# import numpy as np

# # Definición de los datos extraídos
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [1.976, 2.136, 2.264, 2.436, 2.519, 2.648, 2.630, 2.728, 2.792, 2.977, 3.112, 3.196, 3.240, 3.484, 3.646, 3.532] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [3.695, 3.896, 4.100, 4.254, 4.396, 4.541, 4.686, 4.816, 4.858]
# demanda_medio = [np.nan] * 16 + [3.746, 3.988, 4.234, 4.433, 4.622, 4.818, 5.019, 5.207, 5.304]
# demanda_mayor = [np.nan] * 16 + [3.766, 4.043, 4.329, 4.569, 4.803, 5.050, 5.303, 5.550, 5.705]

# # Creación del diccionario de datos
# datos_demanda = {
#     'Año': años,
#     'Demanda (MW) - Histórico': demanda_historico,
#     'Demanda (MW) - Menor': demanda_menor,
#     'Demanda (MW) - Medio': demanda_medio,
#     'Demanda (MW) - Mayor': demanda_mayor
# }

# # Creación del DataFrame
# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce') # Asegura que los tipos sean numéricos

# print("DataFrame de Previsión de Demanda de Potencia:")
# print(df_demanda)

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# # --- Código del Paso 3: Definición del DataFrame ---
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [1.976, 2.136, 2.264, 2.436, 2.519, 2.648, 2.630, 2.728, 2.792, 2.977, 3.112, 3.196, 3.240, 3.484, 3.646, 3.532] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [3.695, 3.896, 4.100, 4.254, 4.396, 4.541, 4.686, 4.816, 4.858]
# demanda_medio = [np.nan] * 16 + [3.746, 3.988, 4.234, 4.433, 4.622, 4.818, 5.019, 5.207, 5.304]
# demanda_mayor = [np.nan] * 16 + [3.766, 4.043, 4.329, 4.569, 4.803, 5.050, 5.303, 5.550, 5.705]

# datos_demanda = {
#     'Año': años,
#     'Demanda (MW) - Histórico': demanda_historico,
#     'Demanda (MW) - Menor': demanda_menor,
#     'Demanda (MW) - Medio': demanda_medio,
#     'Demanda (MW) - Mayor': demanda_mayor
# }

# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce')
# df_demanda.set_index('Año', inplace=True)
# # --- Fin Código del Paso 3 ---


# # --- Generación del Gráfico ---
# plt.figure(figsize=(12, 6))

# # Obtener el último valor histórico para la conexión
# ultimo_historico_valor = df_demanda.loc[2016, 'Demanda (MW) - Histórico']
# ultimo_historico_año = 2016

# # 1. Trazar la serie histórica (2001-2016)
# plt.plot(df_demanda.index[:16], df_demanda['Demanda (MW) - Histórico'].dropna(),
#          marker='s', markersize=4, linestyle='-', color='black', label='Histórico (2001-2016)')

# # 2. Trazar las series de previsión, comenzando desde el último punto histórico (2016) para conectar.
# for columna, color, estilo in [('Demanda (MW) - Menor', 'red', '--'),
#                                ('Demanda (MW) - Medio', 'blue', '-'),
#                                ('Demanda (MW) - Mayor', 'green', '-')]:

#     # Prepara los datos para la conexión: [Último Histórico] + [Previsión 2017-2025]
#     años_conexion = [ultimo_historico_año] + df_demanda.index[16:].tolist()
#     valores_prevision = df_demanda[columna].dropna().tolist()
#     valores_conexion = [ultimo_historico_valor] + valores_prevision

#     # Trazar la línea de conexión/previsión
#     plt.plot(años_conexion, valores_conexion,
#              marker='o', markersize=4, linestyle=estilo, color=color,
#              label=columna.split(' - ')[1] + ' (Previsión)')


# # Configuración del gráfico
# plt.title('Previsión de la Demanda Anual de Potencia Eléctrica (MW) 2001-2025')
# plt.xlabel('Año')
# plt.ylabel('Demanda (MW)')
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.legend(title='Escenario de Crecimiento')

# # Ajustar las etiquetas del eje X para mejor lectura
# plt.xticks(df_demanda.index[::2], rotation=45)
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# ANEXO 3.10) sobre la Previsión de la Demanda Anual de Energía Eléctrica en Bornes de Generación del S.N.I.,

# %%
# import pandas as pd
# import numpy as np

# # Definición de los datos extraídos
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [10.859, 11.541, 12.115, 12.960, 13.769, 14.689, 15.457, 16.315, 16.877, 17.594, 18.645, 19.547, 20.269, 21.461, 22.481, 22.355] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [23.800, 25.395, 27.088, 28.669, 30.164, 31.721, 35.837, 40.329, 44.898]
# demanda_medio = [np.nan] * 16 + [24.050, 25.917, 27.881, 29.765, 31.579, 33.497, 37.999, 42.901, 47.906]
# demanda_mayor = [np.nan] * 16 + [24.272, 26.380, 28.609, 30.782, 32.916, 35.188, 40.074, 45.395, 50.854]

# # Creación del diccionario de datos
# datos_demanda = {
#     'Año': años,
#     'Demanda (GWh) - Histórico': demanda_historico,
#     'Demanda (GWh) - Menor': demanda_menor,
#     'Demanda (GWh) - Medio': demanda_medio,
#     'Demanda (GWh) - Mayor': demanda_mayor
# }

# # Creación del DataFrame
# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce')

# print("DataFrame de Previsión de Demanda de Energía:")
# print(df_demanda)

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# # --- Código del Paso 3: Definición del DataFrame ---
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [10.859, 11.541, 12.115, 12.960, 13.769, 14.689, 15.457, 16.315, 16.877, 17.594, 18.645, 19.547, 20.269, 21.461, 22.481, 22.355] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [23.800, 25.395, 27.088, 28.669, 30.164, 31.721, 35.837, 40.329, 44.898]
# demanda_medio = [np.nan] * 16 + [24.050, 25.917, 27.881, 29.765, 31.579, 33.497, 37.999, 42.901, 47.906]
# demanda_mayor = [np.nan] * 16 + [24.272, 26.380, 28.609, 30.782, 32.916, 35.188, 40.074, 45.395, 50.854]

# datos_demanda = {
#     'Año': años,
#     'Demanda (GWh) - Histórico': demanda_historico,
#     'Demanda (GWh) - Menor': demanda_menor,
#     'Demanda (GWh) - Medio': demanda_medio,
#     'Demanda (GWh) - Mayor': demanda_mayor
# }

# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce')
# df_demanda.set_index('Año', inplace=True)
# # --- Fin Código del Paso 3 ---


# # --- Generación del Gráfico (con corrección de grieta) ---
# plt.figure(figsize=(12, 6))

# # Obtener el último valor histórico para la conexión
# ultimo_historico_valor = df_demanda.loc[2016, 'Demanda (GWh) - Histórico']
# ultimo_historico_año = 2016

# # 1. Trazar la serie histórica (2001-2016)
# plt.plot(df_demanda.index[:16], df_demanda['Demanda (GWh) - Histórico'].dropna(),
#          marker='s', markersize=4, linestyle='-', color='black', label='Histórico (2001-2016)')

# # 2. Trazar las series de previsión, comenzando desde el último punto histórico (2016) para conectar.
# for columna, color, estilo in [('Demanda (GWh) - Menor', 'red', '--'),
#                                ('Demanda (GWh) - Medio', 'blue', '-'),
#                                ('Demanda (GWh) - Mayor', 'green', '-')]:

#     # Prepara los datos para la conexión: [Último Histórico] + [Previsión 2017-2025]
#     años_conexion = [ultimo_historico_año] + df_demanda.index[16:].tolist()
#     valores_prevision = df_demanda[columna].dropna().tolist()
#     valores_conexion = [ultimo_historico_valor] + valores_prevision

#     # Trazar la línea de conexión/previsión
#     plt.plot(años_conexion, valores_conexion,
#              marker='o', markersize=4, linestyle=estilo, color=color,
#              label=columna.split(' - ')[1] + ' (Previsión)')


# # Configuración del gráfico
# plt.title('Previsión de la Demanda Anual de Energía Eléctrica (GWh) 2001-2025')
# plt.xlabel('Año')
# plt.ylabel('Demanda (GWh)')
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.legend(title='Escenario de Crecimiento')

# # Ajustar las etiquetas del eje X para mejor lectura
# plt.xticks(df_demanda.index[::2], rotation=45)
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# ANEXO 3.11: Previsión de la Demanda Anual de Potencia Eléctrica en Bornes de Generación del S.N.I. - Hipótesis No. 5

# %%
# import pandas as pd
# import numpy as np

# # Definición de los datos extraídos
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [2.002, 2.132, 2.223, 2.401, 2.424, 2.642, 2.706, 2.785, 2.768, 2.879, 3.052, 3.207, 3.332, 3.503, 3.670, 3.653] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [3.948, 4.211, 4.481, 4.691, 4.895, 5.115, 5.724, 6.252, 6.684]
# demanda_medio = [np.nan] * 16 + [3.987, 4.293, 4.605, 4.861, 5.113, 5.387, 6.052, 6.640, 7.129]
# demanda_mayor = [np.nan] * 16 + [4.022, 4.364, 4.718, 5.017, 5.316, 5.642, 6.363, 7.010, 7.560]

# # Creación del diccionario de datos
# datos_demanda = {
#     'Año': años,
#     'Demanda (MW) - Histórico': demanda_historico,
#     'Demanda (MW) - Menor': demanda_menor,
#     'Demanda (MW) - Medio': demanda_medio,
#     'Demanda (MW) - Mayor': demanda_mayor
# }

# # Creación del DataFrame
# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce')

# print("DataFrame de Previsión de Demanda de Potencia:")
# print(df_demanda)

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# # --- Código del Paso 3: Definición del DataFrame ---
# años = list(range(2001, 2017)) + list(range(2017, 2026))

# demanda_historico = [2.002, 2.132, 2.223, 2.401, 2.424, 2.642, 2.706, 2.785, 2.768, 2.879, 3.052, 3.207, 3.332, 3.503, 3.670, 3.653] + [np.nan] * 9
# demanda_menor = [np.nan] * 16 + [3.948, 4.211, 4.481, 4.691, 4.895, 5.115, 5.724, 6.252, 6.684]
# demanda_medio = [np.nan] * 16 + [3.987, 4.293, 4.605, 4.861, 5.113, 5.387, 6.052, 6.640, 7.129]
# demanda_mayor = [np.nan] * 16 + [4.022, 4.364, 4.718, 5.017, 5.316, 5.642, 6.363, 7.010, 7.560]

# datos_demanda = {
#     'Año': años,
#     'Demanda (MW) - Histórico': demanda_historico,
#     'Demanda (MW) - Menor': demanda_menor,
#     'Demanda (MW) - Medio': demanda_medio,
#     'Demanda (MW) - Mayor': demanda_mayor
# }

# df_demanda = pd.DataFrame(datos_demanda)
# df_demanda = df_demanda.apply(pd.to_numeric, errors='coerce')
# df_demanda.set_index('Año', inplace=True)
# # --- Fin Código del Paso 3 ---


# # --- Generación del Gráfico (con corrección de grieta) ---
# plt.figure(figsize=(12, 6))

# # Obtener el último valor histórico para la conexión
# ultimo_historico_valor = df_demanda.loc[2016, 'Demanda (MW) - Histórico']
# ultimo_historico_año = 2016

# # 1. Trazar la serie histórica (2001-2016)
# plt.plot(df_demanda.index[:16], df_demanda['Demanda (MW) - Histórico'].dropna(),
#          marker='s', markersize=4, linestyle='-', color='black', label='Histórico (2001-2016)')

# # 2. Trazar las series de previsión, comenzando desde el último punto histórico (2016) para conectar.
# for columna, color, estilo in [('Demanda (MW) - Menor', 'red', '--'),
#                                ('Demanda (MW) - Medio', 'blue', '-'),
#                                ('Demanda (MW) - Mayor', 'green', '-')]:

#     # Prepara los datos para la conexión: [Último Histórico] + [Previsión 2017-2025]
#     años_conexion = [ultimo_historico_año] + df_demanda.index[16:].tolist()
#     valores_prevision = df_demanda[columna].dropna().tolist()
#     valores_conexion = [ultimo_historico_valor] + valores_prevision

#     # Trazar la línea de conexión/previsión
#     plt.plot(años_conexion, valores_conexion,
#              marker='o', markersize=4, linestyle=estilo, color=color,
#              label=columna.split(' - ')[1] + ' (Previsión)')


# # Configuración del gráfico
# plt.title('Previsión de la Demanda Anual de Potencia Eléctrica (MW) 2001-2025')
# plt.xlabel('Año')
# plt.ylabel('Demanda (MW)')
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.legend(title='Escenario de Crecimiento')

# # Ajustar las etiquetas del eje X para mejor lectura
# plt.xticks(df_demanda.index[::2], rotation=45)
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()
