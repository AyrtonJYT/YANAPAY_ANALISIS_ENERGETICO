# %% [markdown]
# <a href="https://colab.research.google.com/github/AyrtonJYT/YANAPAY_ANALISIS_ENERGETICO/blob/main/PME_2023_2032.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Figura No. 1-1. Demanda de Potencia del S.N.I. (MW)
# Fuente: Operador Nacional de Electricidad - CENACE

# %%
# import pandas as pd

# # Datos extraídos del gráfico
# data = {
#     'Mes': ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'],
#     'Demanda 2021 (MW)': [4.018, 4.055, 4.102, 4.076, 4.002, 3.892, 3.949, 3.961, 4.063, 4.065, 4.080, 4.208],
#     'Demanda 2022 (MW)': [4.162, 4.152, 4.253, 4.388, 4.238, 4.077, 4.114, 4.076, 4.147, 4.114, 4.216, 4.262],
#     'Variación (%)': [3.57, 2.41, 3.68, 7.65, 5.89, 4.75, 4.18, 2.90, 2.07, 1.19, 3.34, 1.28]
# }

# # Crear el DataFrame
# df = pd.DataFrame(data)

# # Mostrar el DataFrame
# print("DataFrame de Demanda de Potencia:")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # --- (Código del DataFrame del Paso 3) ---
# data = {
#     'Mes': ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'],
#     'Demanda 2021 (MW)': [4.018, 4.055, 4.102, 4.076, 4.002, 3.892, 3.949, 3.961, 4.063, 4.065, 4.080, 4.208],
#     'Demanda 2022 (MW)': [4.162, 4.152, 4.253, 4.388, 4.238, 4.077, 4.114, 4.076, 4.147, 4.114, 4.216, 4.262],
#     'Variación (%)': [3.57, 2.41, 3.68, 7.65, 5.89, 4.75, 4.18, 2.90, 2.07, 1.19, 3.34, 1.28]
# }
# df = pd.DataFrame(data)
# # ----------------------------------------

# # Configuración de los Meses como índice para el ploteo
# df = df.set_index('Mes')

# # Crear la figura y los ejes
# fig, ax1 = plt.subplots(figsize=(10, 6))

# # GRAFICO PRIMARIO (Ejes Y izquierdos para MW)
# ax1.set_xlabel('Mes')
# ax1.set_ylabel('Demanda de Potencia (MW)', color='blue')
# # Gráfico de Barras para la Demanda 2022 (Similar al original)
# ax1.bar(df.index, df['Demanda 2022 (MW)'], color='#314777', width=0.4, label='2022 (MW)', align='edge')
# # Gráfico de Barras para la Demanda 2021 (Ajustado)
# ax1.bar(df.index, df['Demanda 2021 (MW)'], color='#5e84af', width=-0.4, label='2021 (MW)', align='edge')
# ax1.tick_params(axis='y', labelcolor='blue')
# ax1.set_ylim(3.6, 4.5) # Ajuste de límites similar al gráfico original

# # GRAFICO SECUNDARIO (Ejes Y derechos para Variación %)
# ax2 = ax1.twinx()  # Crea un segundo eje Y compartiendo el eje X
# ax2.set_ylabel('Variación (%)', color='purple')
# # Gráfico de Líneas para la Variación
# line = ax2.plot(df.index, df['Variación (%)'], color='purple', marker='o', label='Variación (%)')
# ax2.tick_params(axis='y', labelcolor='purple')
# ax2.set_ylim(0, 9) # Ajuste de límites similar al gráfico original
# ax2.grid(False) # Desactivar la rejilla en el eje secundario

# # Combinar leyendas
# lines_1, labels_1 = ax1.get_legend_handles_labels()
# lines_2, labels_2 = ax2.get_legend_handles_labels()
# ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=3)

# # Título del Gráfico
# plt.title('Demanda de Potencia del S.N.I. (MW) y Variación (%)')
# plt.grid(axis='y', linestyle='--', alpha=0.7) # Rejilla solo en el eje principal

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Figura No. 1-7. Proyección de la demanda de energía anual en bornes de generación (GWh)-Hipótesis 2

# %%
# import pandas as pd

# # Datos extraídos del gráfico (Proyección 2022-2032)
# data = {
#     'Año': [2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda Tendencial (GWh)': [28.500, 29.500, 30.000, 31.500, 32.500, 34.000, 35.000, 37.000, 38.500, 40.000, 41.334],
#     'Demanda Base (GWh)': [28.500, 30.000, 32.250, 35.500, 38.500, 40.500, 42.000, 44.000, 46.500, 48.500, 50.544]
# }

# # Crear el DataFrame
# df = pd.DataFrame(data)

# # Mostrar el DataFrame
# print("DataFrame de Proyección de Demanda de Energía (GWh):")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # --- (Código del DataFrame del Paso 3) ---
# data = {
#     'Año': [2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda Tendencial (GWh)': [28.500, 29.500, 30.000, 31.500, 32.500, 34.000, 35.000, 37.000, 38.500, 40.000, 41.334],
#     'Demanda Base (GWh)': [28.500, 30.000, 32.250, 35.500, 38.500, 40.500, 42.000, 44.000, 46.500, 48.500, 50.544]
# }
# df = pd.DataFrame(data)
# # ----------------------------------------

# # Configuración del plot
# plt.figure(figsize=(10, 6))

# # Gráfico de Líneas para Demanda Tendencial
# plt.plot(df['Año'], df['Demanda Tendencial (GWh)'],
#          marker='o', linestyle='-', color='#9FBED9', label='Tendencial')

# # Gráfico de Líneas para Demanda Base
# plt.plot(df['Año'], df['Demanda Base (GWh)'],
#          marker='o', linestyle='-', color='#314777', label='Base')

# # Etiquetas, Título y Leyenda
# plt.title('Proyección de la demanda de energía anual (GWh) 2022-2032')
# plt.xlabel('Año')
# plt.ylabel('Energía [GWh]')
# plt.legend(loc='lower center', ncol=2)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.xticks(df['Año']) # Asegurar que se muestren todos los años

# # Agregar los valores finales
# plt.annotate(f"{df['Demanda Tendencial (GWh)'].iloc[-1]:.3f}",
#              (df['Año'].iloc[-1], df['Demanda Tendencial (GWh)'].iloc[-1]),
#              textcoords="offset points", xytext=(5, -5), ha='left')
# plt.annotate(f"{df['Demanda Base (GWh)'].iloc[-1]:.3f}",
#              (df['Año'].iloc[-1], df['Demanda Base (GWh)'].iloc[-1]),
#              textcoords="offset points", xytext=(5, 5), ha='left', fontweight='bold')

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Figura No. 1-8. Proyección de la demanda de potencia máxima anual en bornes de generación (MW)-Hipótesis 2

# %%
# import pandas as pd

# # Datos extraídos del gráfico (Proyección 2022-2032)
# data = {
#     'Año': [2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Potencia Máxima Tendencial (MW)': [4.350, 4.850, 4.900, 5.000, 5.200, 5.350, 5.500, 5.750, 6.000, 6.300, 6.523],
#     'Potencia Máxima Base (MW)': [4.350, 5.000, 5.250, 5.850, 6.300, 6.600, 6.850, 7.150, 7.450, 7.850, 8.126]
# }

# # Crear el DataFrame
# df = pd.DataFrame(data)

# # Mostrar el DataFrame
# print("DataFrame de Proyección de Potencia Máxima (MW):")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # --- (Código del DataFrame del Paso 3) ---
# data = {
#     'Año': [2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Potencia Máxima Tendencial (MW)': [4.350, 4.850, 4.900, 5.000, 5.200, 5.350, 5.500, 5.750, 6.000, 6.300, 6.523],
#     'Potencia Máxima Base (MW)': [4.350, 5.000, 5.250, 5.850, 6.300, 6.600, 6.850, 7.150, 7.450, 7.850, 8.126]
# }
# df = pd.DataFrame(data)
# # ----------------------------------------

# # Configuración del plot
# plt.figure(figsize=(10, 6))

# # Gráfico de Líneas para Demanda Tendencial
# plt.plot(df['Año'], df['Potencia Máxima Tendencial (MW)'],
#          marker='o', linestyle='-', color='#9FBED9', label='Tendencial')

# # Gráfico de Líneas para Demanda Base
# plt.plot(df['Año'], df['Potencia Máxima Base (MW)'],
#          marker='o', linestyle='-', color='#314777', label='Base')

# # Etiquetas, Título y Leyenda
# plt.title('Proyección de la Demanda de Potencia Máxima Anual (MW) 2022-2032')
# plt.xlabel('Año')
# plt.ylabel('Potencia [MW]')
# plt.legend(loc='lower center', ncol=2)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.xticks(df['Año']) # Asegurar que se muestren todos los años

# # Agregar los valores finales
# plt.annotate(f"{df['Potencia Máxima Tendencial (MW)'].iloc[-1]:.3f}",
#              (df['Año'].iloc[-1], df['Potencia Máxima Tendencial (MW)'].iloc[-1]),
#              textcoords="offset points", xytext=(5, -5), ha='left')
# plt.annotate(f"{df['Potencia Máxima Base (MW)'].iloc[-1]:.3f}",
#              (df['Año'].iloc[-1], df['Potencia Máxima Base (MW)'].iloc[-1]),
#              textcoords="offset points", xytext=(5, 5), ha='left', fontweight='bold')

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Figura No. 2-6. Evolución de la Demanda de Potencia Máxima en bornes de generación, periodo 2012-2022
# Fuente: Operador Nacional de Electricidad – CENACE

# %%
# import pandas as pd

# # Datos extraídos del gráfico (Evolución 2012-2022)
# data = {
#     'Año': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#     'Demanda de Potencia Máxima (MW)': [3.207, 3.332, 3.503, 3.670, 3.653, 3.746, 3.933, 3.953, 4.089, 4.208, 4.388]
# }

# # Crear el DataFrame
# df = pd.DataFrame(data)

# # Mostrar el DataFrame
# print("DataFrame de Evolución de Demanda de Potencia Máxima (MW):")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # --- (Código del DataFrame del Paso 3) ---
# data = {
#     'Año': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#     'Demanda de Potencia Máxima (MW)': [3.207, 3.332, 3.503, 3.670, 3.653, 3.746, 3.933, 3.953, 4.089, 4.208, 4.388]
# }
# df = pd.DataFrame(data)
# # ----------------------------------------

# # Configuración del plot
# plt.figure(figsize=(12, 6))

# # Gráfico de Barras
# bar_colors = '#3182bd'
# bars = plt.bar(df['Año'].astype(str), df['Demanda de Potencia Máxima (MW)'],
#                color=bar_colors)

# # Etiquetas, Título y Leyenda (se omite la leyenda por ser una serie única, pero se incluyen las etiquetas)
# plt.title('Evolución de la Demanda de Potencia Máxima (MW), 2012-2022')
# plt.xlabel('Año')
# plt.ylabel('Potencia [MW]')
# plt.grid(axis='y', linestyle='--', alpha=0.7)

# # Agregar etiquetas de valor sobre cada barra
# for bar in bars:
#     yval = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width()/2, yval + 50,
#              f'{yval:.3f}', ha='center', va='bottom', fontsize=9)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Tabla No. 2-3. Demanda de energía mensual S.N.I. (GWh)
# Fuente: Operador Nacional de Electricidad – CENACE

# %%
# import pandas as pd

# # Datos extraídos de la tabla (sin incluir la fila "Total" para el gráfico mensual)
# datos = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#     'Demanda 2021 (GWh)': [2086, 2032, 2348, 2278, 2241, 2156, 2213, 2242, 2214, 2334, 2237, 2347],
#     'Demanda 2022 (GWh)': [2351, 2167, 2471, 2434, 2430, 2195, 2312, 2413, 2312, 2356, 2295, 2444],
#     'Variación (%)': [12.69, 6.64, 5.25, 6.85, 8.47, 1.81, 4.51, 7.60, 4.42, 0.94, 2.59, 4.13]
# }

# # Creación del DataFrame. Las columnas de demanda incluyen la unidad (GWh).
# df = pd.DataFrame(datos)

# # Mostrar el DataFrame
# print("DataFrame con la demanda mensual de energía:")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos de la tabla (sin incluir la fila "Total" para el gráfico mensual)
# datos = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#     'Demanda 2021 (GWh)': [2086, 2032, 2348, 2278, 2241, 2156, 2213, 2242, 2214, 2334, 2237, 2347],
#     'Demanda 2022 (GWh)': [2351, 2167, 2471, 2434, 2430, 2195, 2312, 2413, 2312, 2356, 2295, 2444],
#     'Variación (%)': [12.69, 6.64, 5.25, 6.85, 8.47, 1.81, 4.51, 7.60, 4.42, 0.94, 2.59, 4.13]
# }

# # Creación del DataFrame y se establece la columna 'Mes' como índice para el gráfico
# df = pd.DataFrame(datos).set_index('Mes')

# # Generación del gráfico de líneas
# plt.figure(figsize=(12, 6))

# # Trazar las dos series de demanda
# plt.plot(df.index, df['Demanda 2021 (GWh)'], marker='o', label='Demanda 2021', linestyle='-')
# plt.plot(df.index, df['Demanda 2022 (GWh)'], marker='s', label='Demanda 2022', linestyle='--')

# # Configuración del título y etiquetas de los ejes
# plt.title('Demanda de Energía Mensual del S.N.I. (2021 vs 2022)')
# plt.xlabel('Mes')
# plt.ylabel('Demanda de Energía (GWh)')

# # Añadir la leyenda y una cuadrícula
# plt.legend(title='Año')
# plt.grid(True, linestyle=':', alpha=0.6)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Figura No. 2-7. Demanda de energía a nivel de bornes de generación en el S.N.I., en el periodo 2012-2022
# Fuente: Operador Nacional de Electricidad - CENACE

# %%
# import pandas as pd

# # Datos extraídos del gráfico
# datos = {
#     'Año': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#     'Energía (GWh)': [19547, 20269, 21461, 22481, 22355, 23031, 24062, 25387, 25120, 26728, 28181],
#     'Tasa Crecimiento (%)': [4.83, 3.70, 5.88, 4.75, -0.56, 3.03, 4.48, 5.51, -1.05, 6.40, 5.44]
# }

# # Creación del DataFrame, incluyendo las unidades en los nombres de las columnas
# df = pd.DataFrame(datos)

# # Mostrar el DataFrame
# print("DataFrame con la evolución de la demanda de energía:")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos del gráfico
# datos = {
#     'Año': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#     'Energía (GWh)': [19547, 20269, 21461, 22481, 22355, 23031, 24062, 25387, 25120, 26728, 28181],
#     'Tasa Crecimiento (%)': [4.83, 3.70, 5.88, 4.75, -0.56, 3.03, 4.48, 5.51, -1.05, 6.40, 5.44]
# }

# df = pd.DataFrame(datos).set_index('Año')

# # Configuración del gráfico combinado (Ejes gemelos)
# fig, ax1 = plt.subplots(figsize=(12, 7))

# # Eje 1 (Barras para la Energía - GWh)
# color1 = 'tab:blue'
# ax1.set_xlabel('Año')
# ax1.set_ylabel('Energía (GWh)', color=color1)
# ax1.bar(df.index.astype(str), df['Energía (GWh)'], color=color1, alpha=0.8, label='Energía (GWh)')
# ax1.tick_params(axis='y', labelcolor=color1)

# # Eje 2 (Línea para la Tasa de Crecimiento - %)
# ax2 = ax1.twinx()  # Crea un segundo eje Y que comparte el mismo eje X
# color2 = 'tab:orange'
# ax2.set_ylabel('Tasa Crecimiento (%)', color=color2)
# ax2.plot(df.index.astype(str), df['Tasa Crecimiento (%)'], color=color2, marker='o', linestyle='-', linewidth=2, label='Crecimiento (%)')
# ax2.tick_params(axis='y', labelcolor=color2)
# ax2.set_ylim(-2.0, 7.0) # Ajustar límites para reflejar el rango del gráfico original

# # Título
# plt.title('Evolución de la Demanda de Energía y Tasa de Crecimiento Anual (2012-2022)')

# # Leyenda (requiere combinar las leyendas de ambos ejes)
# lines, labels = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
# ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# # Mostrar el gráfico
# fig.tight_layout()
# plt.show()

# %% [markdown]
# Figura No. 3-1. Evolución de la demanda nacional de energía eléctrica del S.N.I.

# %%
# import pandas as pd

# # Datos extraídos del gráfico (2010 a 2022)
# datos = {
#     'Año': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#     'Energía (GWh)': [17594, 18645, 19547, 20269, 21461, 22481, 22355, 23031, 24062, 25387, 25120, 26728, 28181],
#     'Tasa Crecimiento (%)': [4.25, 5.97, 4.83, 3.70, 5.88, 4.75, -0.56, 3.03, 4.48, 5.51, -1.05, 6.40, 5.44]
# }

# # Creación del DataFrame, incluyendo las unidades en los nombres de las columnas
# df = pd.DataFrame(datos)

# # Mostrar el DataFrame
# print("DataFrame con la evolución de la demanda nacional de energía:")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos del gráfico (2010 a 2022)
# datos = {
#     'Año': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#     'Energía (GWh)': [17594, 18645, 19547, 20269, 21461, 22481, 22355, 23031, 24062, 25387, 25120, 26728, 28181],
#     'Tasa Crecimiento (%)': [4.25, 5.97, 4.83, 3.70, 5.88, 4.75, -0.56, 3.03, 4.48, 5.51, -1.05, 6.40, 5.44]
# }

# # Crear el DataFrame y establecer 'Año' como índice
# df = pd.DataFrame(datos).set_index('Año')
# años_str = df.index.astype(str)

# # Configuración del gráfico combinado (Ejes gemelos)
# fig, ax1 = plt.subplots(figsize=(14, 7))

# # --- Eje 1 (Barras para la Energía - GWh) ---
# color1 = 'tab:grey'
# ax1.set_xlabel('Año')
# ax1.set_ylabel('Energía (GWh)', color=color1)
# ax1.bar(años_str, df['Energía (GWh)'], color=color1, alpha=0.8, label='GWh')
# ax1.tick_params(axis='y', labelcolor=color1)
# ax1.set_ylim(0, 30000) # Ajustar límites para reflejar el gráfico original

# # --- Eje 2 (Línea para la Tasa de Crecimiento - %) ---
# ax2 = ax1.twinx()  # Crea un segundo eje Y que comparte el mismo eje X
# color2 = 'tab:orange'
# ax2.set_ylabel('Tasa Crecimiento (%)', color=color2)
# ax2.plot(años_str, df['Tasa Crecimiento (%)'], color=color2, marker='o', linestyle='-', linewidth=2, label='%')
# ax2.tick_params(axis='y', labelcolor=color2)
# ax2.set_ylim(-2.0, 7.0) # Ajustar límites para reflejar el rango del gráfico original
# ax2.axhline(0, color='red', linestyle=':', alpha=0.5) # Línea de referencia en 0%

# # Título
# plt.title('Evolución de la Demanda Nacional de Energía Eléctrica del S.N.I. (2010-2022)')

# # Leyenda (combinando las leyendas de ambos ejes)
# lines, labels = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
# ax2.legend(lines + lines2, labels + labels2, loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=2)

# # Mostrar el gráfico
# fig.tight_layout()
# plt.show()

# %% [markdown]
# Figura No. 3-2. Seguimiento mensual de la demanda de energía eléctrica – 2022

# %% [markdown]
# Tabla No. 3-1. Variación mensual de la demanda de potencia (MW)
# Fuente: CENACE

# %%
# import pandas as pd
# import numpy as np # Necesario para manejar la fila de 'Demanda Máxima'

# # Datos extraídos de la tabla (incluyendo la fila de resumen para completitud)
# datos_demanda = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre', 'Demanda Máxima'],
#     'Demanda (MW) - 2021': [4.018, 4.055, 4.102, 4.076, 4.002, 3.892, 3.949, 3.961, 4.063, 4.065, 4.080, 4.208, 4.208],
#     'Demanda (MW) - 2022': [4.162, 4.152, 4.253, 4.388, 4.238, 4.077, 4.114, 4.076, 4.147, 4.114, 4.216, 4.262, 4.388],
#     'Variación (%)': [3.57, 2.41, 3.68, 7.65, 5.89, 4.75, 4.18, 2.90, 2.07, 1.19, 3.34, 1.28, 4.28]
# }

# # Creación del DataFrame
# df_demanda = pd.DataFrame(datos_demanda)

# # Separar la fila de 'Demanda Máxima' (última fila) y el dataset mensual
# df_mensual = df_demanda.iloc[:-1].set_index('Mes')
# df_maxima = df_demanda.iloc[-1:]

# print("--- DataFrame Mensual ---")
# print(df_mensual)
# print("\n--- DataFrame Máximo ---")
# print(df_maxima)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # --- Creación del DataFrame Mensual (usando solo datos para graficar) ---
# datos_plot = {
#     'Mes': ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'],
#     'Demanda (MW) - 2021': [4.018, 4.055, 4.102, 4.076, 4.002, 3.892, 3.949, 3.961, 4.063, 4.065, 4.080, 4.208],
#     'Demanda (MW) - 2022': [4.162, 4.152, 4.253, 4.388, 4.238, 4.077, 4.114, 4.076, 4.147, 4.114, 4.216, 4.262]
# }

# df_plot = pd.DataFrame(datos_plot).set_index('Mes')

# # --- Generación del Gráfico de Líneas ---
# plt.figure(figsize=(12, 6))

# # Trazar las dos series de demanda
# # La función .plot() de pandas usa matplotlib internamente
# df_plot.plot(kind='line', marker='o', linestyle='-', ax=plt.gca())

# # Añadir título y etiquetas
# plt.title('Demanda Máxima Mensual de Potencia (MW)')
# plt.xlabel('Mes')
# plt.ylabel('Demanda (MW)')

# # Ajustar leyenda y rejilla
# plt.legend(title='Año', loc='upper right')
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.xticks(rotation=45)
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# Tabla No. 3-1. Variación mensual de la demanda de potencia (MW)
# Fuente: CENACE

# %%
# import pandas as pd
# import numpy as np

# # Datos de variación extraídos del DataFrame mensual (excluyendo la fila de resumen)
# variacion_porcentual = [3.57, 2.41, 3.68, 7.65, 5.89, 4.75, 4.18, 2.90, 2.07, 1.19, 3.34, 1.28]

# # Crear una Serie de pandas para facilitar los cálculos
# s_variacion = pd.Series(variacion_porcentual)

# # 1. Cálculo de la Variación Promedio (Media)
# media = s_variacion.mean()

# # 2. Cálculo de la Variación Mediana
# mediana = s_variacion.median()

# # 3. Cálculo de la Desviación Estándar para medir la dispersión
# std_dev = s_variacion.std()

# print(f"✅ Análisis Estadístico de la Variación % (2022 vs 2021)")
# print("---")
# print(f"Variación Promedio (Media): {media:.3f}%")
# print(f"Variación Mediana: {mediana:.3f}%")
# print(f"Desviación Estándar: {std_dev:.3f}%")
# print(f"Rango (Max - Min): {s_variacion.max() - s_variacion.min():.2f}%")

# %% [markdown]
# Figura No. 3-9. Energía facturada por grupo de consumo 2012 –20224

# %%
# import pandas as pd

# # Los años serán el índice (filas) del DataFrame para facilitar el análisis de series de tiempo
# data = {
#     'Residencial (GWh)': [5.629, 5.881, 6.364, 6.928, 7.105, 7.298, 7.400, 7.656, 8.063, 7.959, 7.833],
#     'Industrial (GWh)': [4.686, 4.684, 4.975, 4.973, 4.778, 4.925, 5.092, 5.054, 4.821, 5.660, 6.137],
#     'Comercial (GWh)': [3.209, 3.486, 3.786, 3.981, 3.838, 3.843, 3.831, 3.924, 3.420, 3.741, 4.000],
#     'Otros (GWh)': [1.411, 1.728, 1.811, 1.980, 2.049, 2.149, 2.368, 2.463, 2.349, 2.431, 2.641],
#     'Alumbrado Público (GWh)': [0.913, 0.964, 1.023, 1.081, 1.127, 1.213, 1.310, 1.382, 1.443, 1.457, 1.521],
#     'Total (GWh)': [15.848, 16.743, 17.958, 18.943, 18.897, 19.428, 20.001, 20.480, 20.095, 21.248, 22.132]
# }

# index_años = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# df_energia = pd.DataFrame(data, index=index_años)

# # Muestra el DataFrame creado
# print("DataFrame de Energía Facturada (GWh):\n")
# print(df_energia)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Los años serán el índice (filas) del DataFrame para facilitar el análisis de series de tiempo
# data = {
#     'Residencial (GWh)': [5.629, 5.881, 6.364, 6.928, 7.105, 7.298, 7.400, 7.656, 8.063, 7.959, 7.833],
#     'Industrial (GWh)': [4.686, 4.684, 4.975, 4.973, 4.778, 4.925, 5.092, 5.054, 4.821, 5.660, 6.137],
#     'Comercial (GWh)': [3.209, 3.486, 3.786, 3.981, 3.838, 3.843, 3.831, 3.924, 3.420, 3.741, 4.000],
#     'Otros (GWh)': [1.411, 1.728, 1.811, 1.980, 2.049, 2.149, 2.368, 2.463, 2.349, 2.431, 2.641],
#     'Alumbrado Público (GWh)': [0.913, 0.964, 1.023, 1.081, 1.127, 1.213, 1.310, 1.382, 1.443, 1.457, 1.521],
#     'Total (GWh)': [15.848, 16.743, 17.958, 18.943, 18.897, 19.428, 20.001, 20.480, 20.095, 21.248, 22.132]
# }

# index_años = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# df_energia = pd.DataFrame(data, index=index_años)

# # --- Generación del Gráfico de Líneas ---
# plt.figure(figsize=(10, 6))

# # Se excluye la columna 'Total' para graficar solo los grupos de consumo
# df_energia.drop(columns=['Total (GWh)']).plot(kind='line', ax=plt.gca(), marker='o', linewidth=2)

# plt.title('Energía Facturada por Grupo de Consumo (2012-2022)')
# plt.xlabel('Año')
# plt.ylabel('Energía Facturada (GWh)')
# plt.legend(title='Grupo de Consumo', loc='upper left', bbox_to_anchor=(1.05, 1))
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.xticks(index_años, rotation=45) # Asegura que todos los años se muestren en el eje X
# plt.tight_layout() # Ajusta el gráfico para que no se corten las etiquetas/leyenda

# plt.show()

# %% [markdown]
# Figura No. 3-22. Proyección de la demanda de energía por grupo de consumo (GWh)

# %%
# import pandas as pd

# # Datos extraídos y organizados por grupo de consumo
# data = {
#     'Otros (GWh)': [2.841, 2.701, 2.831, 2.968, 3.112, 3.283, 3.421, 3.586, 3.760, 3.941, 4.132],
#     'AP (GWh)': [1.521, 1.556, 1.620, 1.697, 1.756, 1.829, 1.904, 1.983, 2.065, 2.150, 2.239],
#     'Industrial (GWh)': [6.137, 8.026, 8.491, 8.983, 9.504, 10.056, 10.639, 11.256, 11.909, 12.598, 13.330],
#     'Comercial (GWh)': [4.000, 3.984, 4.148, 4.300, 4.476, 4.649, 4.828, 5.018, 5.219, 5.411, 5.621],
#     'Residencial (GWh)': [7.633, 8.079, 8.288, 8.615, 8.905, 8.974, 9.239, 9.595, 9.880, 10.269, 10.561],
#     'Total (GWh)': [22.132, 24.355, 25.377, 26.562, 27.753, 28.789, 30.032, 31.438, 32.923, 34.371, 35.883]
# }

# index_años = list(range(2022, 2033)) # Genera la lista de años de 2022 a 2032

# df_proyeccion = pd.DataFrame(data, index=index_años)

# # Muestra el DataFrame creado
# print("DataFrame de Proyección de Energía Facturada (GWh):\n")
# print(df_proyeccion)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos y organizados por grupo de consumo
# data = {
#     'Otros (GWh)': [2.841, 2.701, 2.831, 2.968, 3.112, 3.283, 3.421, 3.586, 3.760, 3.941, 4.132],
#     'AP (GWh)': [1.521, 1.556, 1.620, 1.697, 1.756, 1.829, 1.904, 1.983, 2.065, 2.150, 2.239],
#     'Industrial (GWh)': [6.137, 8.026, 8.491, 8.983, 9.504, 10.056, 10.639, 11.256, 11.909, 12.598, 13.330],
#     'Comercial (GWh)': [4.000, 3.984, 4.148, 4.300, 4.476, 4.649, 4.828, 5.018, 5.219, 5.411, 5.621],
#     'Residencial (GWh)': [7.633, 8.079, 8.288, 8.615, 8.905, 8.974, 9.239, 9.595, 9.880, 10.269, 10.561],
#     'Total (GWh)': [22.132, 24.355, 25.377, 26.562, 27.753, 28.789, 30.032, 31.438, 32.923, 34.371, 35.883]
# }

# index_años = list(range(2022, 2033))

# df_proyeccion = pd.DataFrame(data, index=index_años)

# # --- Generación del Gráfico de Barras Apiladas ---

# # Se seleccionan solo los grupos de consumo (excluyendo el Total)
# df_plot = df_proyeccion.drop(columns=['Total (GWh)'])

# plt.figure(figsize=(12, 7))

# # Gráfico de barras apiladas
# df_plot.plot(kind='bar', stacked=True, ax=plt.gca())

# # Línea de la serie 'Total' (opcional, para replicar el gráfico original con la tendencia)
# plt.plot(df_proyeccion.index, df_proyeccion['Total (GWh)'], marker='o', color='darkblue', label='Total (GWh)', linewidth=2)

# plt.title('Proyección de Energía Facturada por Grupo de Consumo (2022-2032)')
# plt.xlabel('Año')
# plt.ylabel('Energía (GWh)')
# plt.legend(title='Grupo de Consumo', loc='upper left', bbox_to_anchor=(1.05, 1))
# plt.xticks(rotation=45) # Gira las etiquetas del eje X para mejor lectura
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()

# plt.show()

# %% [markdown]
# Tabla No. 3-15. Energía mensual requerida en bornes de generación (GWh)

# %%
# import pandas as pd

# # Datos organizados para que las columnas sean los años
# data = {
#     '2023 (GWh)': [2.494, 2.284, 2.515, 2.456, 2.499, 2.360, 2.326, 2.334, 2.332, 2.358, 2.398, 2.468, 28.824],
#     '2024 (GWh)': [2.591, 2.372, 2.608, 2.548, 2.589, 2.444, 2.406, 2.416, 2.417, 2.438, 2.488, 2.556, 29.872],
#     '2025 (GWh)': [2.702, 2.472, 2.716, 2.653, 2.695, 2.543, 2.499, 2.511, 2.516, 2.532, 2.591, 2.659, 31.090],
#     '2026 (GWh)': [2.820, 2.579, 2.829, 2.765, 2.806, 2.647, 2.598, 2.612, 2.621, 2.632, 2.700, 2.768, 32.378],
#     '2027 (GWh)': [2.919, 2.668, 2.924, 2.858, 2.899, 2.734, 2.679, 2.696, 2.709, 2.713, 2.792, 2.858, 33.447],
#     '2028 (GWh)': [3.045, 2.782, 3.046, 2.977, 3.018, 2.845, 2.785, 2.804, 2.821, 2.820, 2.909, 2.974, 34.826],
#     '2029 (GWh)': [3.123, 2.865, 3.169, 3.093, 3.155, 2.983, 2.957, 2.959, 2.940, 2.998, 3.019, 3.120, 36.383],
#     '2030 (GWh)': [3.275, 3.003, 3.315, 3.237, 3.299, 3.117, 3.084, 3.089, 3.075, 3.127, 3.160, 3.261, 38.042],
#     '2031 (GWh)': [3.423, 3.136, 3.458, 3.377, 3.438, 3.247, 3.207, 3.215, 3.207, 3.251, 3.296, 3.396, 39.651],
#     '2032 (GWh)': [3.577, 3.276, 3.607, 3.523, 3.583, 3.384, 3.336, 3.347, 3.344, 3.381, 3.439, 3.539, 41.334]
# }

# index_meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre', 'Total']

# df_mensual = pd.DataFrame(data, index=index_meses)

# # Muestra el DataFrame creado
# print("DataFrame de Proyección de Energía Facturada Mensual (GWh):\n")
# print(df_mensual)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos organizados para que las columnas sean los años
# data = {
#     '2023 (GWh)': [2.494, 2.284, 2.515, 2.456, 2.499, 2.360, 2.326, 2.334, 2.332, 2.358, 2.398, 2.468, 28.824],
#     '2024 (GWh)': [2.591, 2.372, 2.608, 2.548, 2.589, 2.444, 2.406, 2.416, 2.417, 2.438, 2.488, 2.556, 29.872],
#     '2025 (GWh)': [2.702, 2.472, 2.716, 2.653, 2.695, 2.543, 2.499, 2.511, 2.516, 2.532, 2.591, 2.659, 31.090],
#     '2026 (GWh)': [2.820, 2.579, 2.829, 2.765, 2.806, 2.647, 2.598, 2.612, 2.621, 2.632, 2.700, 2.768, 32.378],
#     '2027 (GWh)': [2.919, 2.668, 2.924, 2.858, 2.899, 2.734, 2.679, 2.696, 2.709, 2.713, 2.792, 2.858, 33.447],
#     '2028 (GWh)': [3.045, 2.782, 3.046, 2.977, 3.018, 2.845, 2.785, 2.804, 2.821, 2.820, 2.909, 2.974, 34.826],
#     '2029 (GWh)': [3.123, 2.865, 3.169, 3.093, 3.155, 2.983, 2.957, 2.959, 2.940, 2.998, 3.019, 3.120, 36.383],
#     '2030 (GWh)': [3.275, 3.003, 3.315, 3.237, 3.299, 3.117, 3.084, 3.089, 3.075, 3.127, 3.160, 3.261, 38.042],
#     '2031 (GWh)': [3.423, 3.136, 3.458, 3.377, 3.438, 3.247, 3.207, 3.215, 3.207, 3.251, 3.296, 3.396, 39.651],
#     '2032 (GWh)': [3.577, 3.276, 3.607, 3.523, 3.583, 3.384, 3.336, 3.347, 3.344, 3.381, 3.439, 3.539, 41.334]
# }

# index_meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre', 'Total']

# df_mensual = pd.DataFrame(data, index=index_meses)

# # --- Generación del Gráfico de Barras para comparar estacionalidad ---

# # Seleccionar solo los meses (excluir el Total) y los años 2023 y 2032
# df_plot = df_mensual.drop('Total').filter(items=['2023 (GWh)', '2032 (GWh)'])

# # Trazar el gráfico de barras comparativo
# plt.figure(figsize=(10, 6))

# df_plot.plot(kind='bar', ax=plt.gca())

# plt.title('Comparación de la Proyección Mensual de Energía Facturada: 2023 vs 2032')
# plt.xlabel('Mes')
# plt.ylabel('Energía Facturada (GWh)')
# plt.legend(title='Año Proyectado')
# plt.xticks(rotation=45)
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()

# plt.show()

# %% [markdown]
# Tabla No. 3-16. Potencia coincidente con la máxima demanda del S.N.I. (MW)

# %%
# import pandas as pd

# # Los datos se organizan por año como columna, y las empresas como filas
# data = {
#     '2023 (MW)': [19, 239, 102, 1083, 512, 88, 317, 94, 161, 142, 93, 133, 9, 225, 68, 114, 754, 73, 69, 4296],
#     '2024 (MW)': [20, 244, 105, 1119, 524, 90, 321, 99, 168, 147, 96, 137, 10, 234, 73, 117, 780, 75, 71, 4430],
#     '2025 (MW)': [20, 250, 108, 1154, 540, 92, 329, 107, 174, 152, 100, 143, 10, 244, 78, 121, 815, 78, 74, 4588],
#     '2026 (MW)': [20, 259, 112, 1198, 560, 95, 339, 114, 181, 157, 105, 148, 10, 254, 83, 125, 848, 81, 77, 4765],
#     '2027 (MW)': [21, 266, 114, 1237, 576, 97, 346, 121, 187, 161, 108, 153, 11, 261, 89, 128, 869, 83, 78, 4905],
#     '2028 (MW)': [21, 276, 118, 1288, 598, 99, 357, 130, 194, 167, 113, 158, 11, 271, 94, 132, 903, 86, 81, 5099],
#     '2029 (MW)': [22, 287, 123, 1346, 624, 103, 371, 140, 203, 174, 118, 165, 11, 283, 101, 137, 942, 90, 84, 5323],
#     '2030 (MW)': [23, 299, 127, 1407, 652, 107, 386, 150, 212, 181, 123, 172, 12, 295, 107, 143, 985, 94, 88, 5562],
#     '2031 (MW)': [23, 311, 132, 1467, 680, 110, 400, 161, 222, 188, 128, 178, 12, 307, 114, 148, 1022, 97, 91, 5792],
#     '2032 (MW)': [24, 324, 137, 1531, 710, 114, 414, 171, 232, 195, 134, 185, 13, 319, 121, 153, 1062, 101, 94, 6032]
# }

# index_empresas = [
#     'CNEL Bolívar', 'CNEL El Oro', 'CNEL Esmeraldas', 'CNEL Guayaquil', 'CNEL Guayas Los Ríos',
#     'CNEL Los Ríos', 'CNEL Manabí', 'CNEL Milagro', 'CNEL Sta. Elena', 'CNEL Sto. Domingo',
#     'CNEL Sucumbíos', 'E.E. Ambato', 'E.E. Azogues', 'E.E. Centro Sur', 'E.E. Cotopaxi',
#     'E.E. Norte', 'E.E. Quito', 'E.E. Riobamba', 'E.E. Sur', 'Total'
# ]

# df_demanda_potencia = pd.DataFrame(data, index=index_empresas)

# # Muestra el DataFrame creado
# print("DataFrame de Proyección de Demanda de Potencia (MW):\n")
# print(df_demanda_potencia)

# %% [markdown]
# Tabla No. 3-17. Previsión mensual de la potencia máxima en bornes de generación (MW)

# %%
# import pandas as pd

# # Datos extraídos de la tabla: Previsión mensual de Potencia Máxima (MW)
# data = {
#     'Mes': [
#         'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
#         'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre',
#         'Pot. Máx.' # Fila de Potencia Máxima Anual
#     ],
#     '2023 (MW)': [4.419, 4.357, 4.416, 4.413, 4.400, 4.339, 4.232, 4.175, 4.321, 4.382, 4.366, 4.495, 4.495],
#     '2024 (MW)': [4.628, 4.555, 4.620, 4.610, 4.596, 4.537, 4.421, 4.357, 4.514, 4.578, 4.554, 4.692, 4.692],
#     '2025 (MW)': [4.884, 4.799, 4.870, 4.853, 4.838, 4.780, 4.653, 4.583, 4.752, 4.819, 4.787, 4.936, 4.936],
#     '2026 (MW)': [5.106, 5.009, 5.087, 5.063, 5.047, 4.990, 4.854, 4.777, 4.957, 5.028, 4.988, 5.147, 5.147],
#     '2027 (MW)': [5.267, 5.159, 5.242, 5.211, 5.193, 5.140, 4.996, 4.912, 5.102, 5.175, 5.127, 5.294, 5.294],
#     '2028 (MW)': [5.479, 5.360, 5.449, 5.411, 5.392, 5.340, 5.187, 5.096, 5.297, 5.374, 5.318, 5.494, 5.494],
#     '2029 (MW)': [5.725, 5.592, 5.688, 5.643, 5.622, 5.572, 5.409, 5.310, 5.523, 5.604, 5.539, 5.726, 5.726],
#     '2030 (MW)': [5.806, 5.762, 5.827, 5.850, 5.837, 5.737, 5.612, 5.556, 5.731, 5.808, 5.818, 5.974, 5.974],
#     '2031 (MW)': [6.062, 6.002, 6.075, 6.088, 6.074, 5.977, 5.840, 5.775, 5.964, 6.045, 6.044, 6.212, 6.212],
#     '2032 (MW)': [6.329, 6.253, 6.334, 6.338, 6.322, 6.227, 6.079, 6.004, 6.208, 6.293, 6.281, 6.461, 6.461]
# }

# df_potencia = pd.DataFrame(data)

# # Mostrar las primeras filas del DataFrame (opcional)
# print("DataFrame de Previsión de Potencia Máxima:")
# print(df_potencia.head())

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # --- Creación del DataFrame (Mismo código del paso 3) ---
# data = {
#     'Mes': [
#         'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
#         'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre',
#         'Pot. Máx.' # Fila de Potencia Máxima Anual
#     ],
#     '2023 (MW)': [4.419, 4.357, 4.416, 4.413, 4.400, 4.339, 4.232, 4.175, 4.321, 4.382, 4.366, 4.495, 4.495],
#     '2024 (MW)': [4.628, 4.555, 4.620, 4.610, 4.596, 4.537, 4.421, 4.357, 4.514, 4.578, 4.554, 4.692, 4.692],
#     '2025 (MW)': [4.884, 4.799, 4.870, 4.853, 4.838, 4.780, 4.653, 4.583, 4.752, 4.819, 4.787, 4.936, 4.936],
#     '2026 (MW)': [5.106, 5.009, 5.087, 5.063, 5.047, 4.990, 4.854, 4.777, 4.957, 5.028, 4.988, 5.147, 5.147],
#     '2027 (MW)': [5.267, 5.159, 5.242, 5.211, 5.193, 5.140, 4.996, 4.912, 5.102, 5.175, 5.127, 5.294, 5.294],
#     '2028 (MW)': [5.479, 5.360, 5.449, 5.411, 5.392, 5.340, 5.187, 5.096, 5.297, 5.374, 5.318, 5.494, 5.494],
#     '2029 (MW)': [5.725, 5.592, 5.688, 5.643, 5.622, 5.572, 5.409, 5.310, 5.523, 5.604, 5.539, 5.726, 5.726],
#     '2030 (MW)': [5.806, 5.762, 5.827, 5.850, 5.837, 5.737, 5.612, 5.556, 5.731, 5.808, 5.818, 5.974, 5.974],
#     '2031 (MW)': [6.062, 6.002, 6.075, 6.088, 6.074, 5.977, 5.840, 5.775, 5.964, 6.045, 6.044, 6.212, 6.212],
#     '2032 (MW)': [6.329, 6.253, 6.334, 6.338, 6.322, 6.227, 6.079, 6.004, 6.208, 6.293, 6.281, 6.461, 6.461]
# }
# df_potencia = pd.DataFrame(data)

# # Preparación para el gráfico: Filtrar la fila de Pot. Máx. y seleccionar años.
# df_plot = df_potencia.iloc[:-1].set_index('Mes') # Excluir 'Pot. Máx.' y establecer 'Mes' como índice
# years_to_plot = ['2023 (MW)', '2025 (MW)', '2027 (MW)', '2029 (MW)', '2032 (MW)']

# # --- Generación del Gráfico de Líneas ---
# plt.figure(figsize=(12, 6))

# for col in years_to_plot:
#     plt.plot(df_plot.index, df_plot[col], label=col.replace(' (MW)', ''), marker='o', linestyle='-')

# # Configuración del gráfico
# plt.title('Previsión de Potencia Máxima Mensual en Bornes de Generación (MW)', fontsize=16)
# plt.xlabel('Mes', fontsize=12)
# plt.ylabel('Potencia Máxima (MW)', fontsize=12)
# plt.legend(title='Año', loc='upper left')
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.xticks(rotation=45) # Rotar etiquetas del eje X para mejor legibilidad
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# Tabla No. 3-24. Proyección de la demanda de energía en barras de subestación de entrega – Hipótesis No. 2

# %%
# import pandas as pd

# # Datos de la Proyección de la demanda anual de energía eléctrica
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda Tendencial (GWh)': [27.860, 28.871, 30.044, 31.288, 32.323, 33.657, 35.163, 36.769, 38.328, 39.959],
#     'Demanda Caso Base (GWh)': [28.719, 30.269, 32.132, 33.932, 35.271, 36.882, 38.576, 40.333, 41.991, 43.689],
#     'Crecimiento Tendencial (%)': [0.7, 3.6, 4.1, 4.1, 3.3, 4.1, 4.5, 4.6, 4.2, 4.3],
#     'Crecimiento Caso Base (%)': [3.8, 5.4, 6.2, 5.6, 3.9, 4.6, 4.6, 4.6, 4.1, 4.0]
# }

# df_demanda = pd.DataFrame(data)

# # Añadir las filas de resumen de crecimiento, si se desea
# crec_resumen = {
#     'Año': 'Crec. 2023-2032',
#     'Demanda Tendencial (GWh)': 4.09,
#     'Demanda Caso Base (GWh)': 4.77,
#     'Crecimiento Tendencial (%)': pd.NA,
#     'Crecimiento Caso Base (%)': pd.NA
# }
# df_demanda = pd.concat([df_demanda, pd.Series(crec_resumen).to_frame().T], ignore_index=True)

# print("DataFrame de Proyección de Demanda de Energía:")
# print(df_demanda)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # --- Creación del DataFrame (Mismo código del paso 3, pero solo con datos anuales) ---
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda Tendencial (GWh)': [27.860, 28.871, 30.044, 31.288, 32.323, 33.657, 35.163, 36.769, 38.328, 39.959],
#     'Demanda Caso Base (GWh)': [28.719, 30.269, 32.132, 33.932, 35.271, 36.882, 38.576, 40.333, 41.991, 43.689],
#     'Crecimiento Tendencial (%)': [0.7, 3.6, 4.1, 4.1, 3.3, 4.1, 4.5, 4.6, 4.2, 4.3],
#     'Crecimiento Caso Base (%)': [3.8, 5.4, 6.2, 5.6, 3.9, 4.6, 4.6, 4.6, 4.1, 4.0]
# }
# df_plot = pd.DataFrame(data).set_index('Año')


# # --- Generación del Gráfico de Líneas para la Demanda (GWh) ---
# plt.figure(figsize=(10, 6))

# # Trazar la demanda tendencial
# plt.plot(df_plot.index, df_plot['Demanda Tendencial (GWh)'],
#          label='Demanda Tendencial (GWh)',
#          marker='o', linestyle='-', color='skyblue')

# # Trazar la demanda caso base
# plt.plot(df_plot.index, df_plot['Demanda Caso Base (GWh)'],
#          label='Demanda Caso Base (GWh)',
#          marker='s', linestyle='--', color='darkorange')

# # Configuración del gráfico
# plt.title('Proyección de la Demanda Anual de Energía Eléctrica (2023-2032)', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda de Energía (GWh)', fontsize=12)
# plt.legend(loc='upper left')
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.xticks(df_plot.index.astype(int))  #Asegurar que los años se muestren como enteros
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# Tabla No. 3-25. Proyección de la demanda de potencia en barras de subestación de entrega – Hipótesis No. 2

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Datos extraídos de la tabla
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda_Tendencial (MW)': [4296.0, 4430.0, 4588.0, 4765.0, 4905.0, 5099.0, 5323.0, 5562.0, 5792.0, 6032.0],
#     'Demanda_CasoBase (MW)': [4380.0, 4569.0, 4807.0, 5041.0, 5210.0, 5432.0, 5677.0, 5932.0, 6173.0, 6421.0],
#     'TasaCrec_Tendencial (%)': [0.6, 3.1, 3.6, 3.9, 2.9, 3.9, 4.4, 4.5, 4.1, 4.1],
#     'TasaCrec_CasoBase (%)': [2.6, 4.3, 5.2, 4.9, 3.4, 4.3, 4.5, 4.5, 4.1, 4.0]
# }

# # Creación del DataFrame
# df_demanda = pd.DataFrame(data)

# # Establecer el 'Año' como índice para mejor manejo de series temporales
# df_demanda.set_index('Año', inplace=True)

# print("DataFrame de Proyección de Demanda de Potencia:")
# print(df_demanda)
# # (Continuación del bloque de código anterior)

# # Generación del gráfico de líneas para la Demanda de Potencia (MW)
# plt.figure(figsize=(10, 6))

# # Trazar las dos series de demanda de potencia
# df_demanda['Demanda_Tendencial (MW)'].plot(kind='line', marker='o', label='Demanda Tendencial')
# df_demanda['Demanda_CasoBase (MW)'].plot(kind='line', marker='x', label='Demanda Caso Base')

# # Configuración del gráfico
# plt.title('Proyección de la Demanda Anual de Potencia Eléctrica (2023-2032)')
# plt.xlabel('Año')
# plt.ylabel('Demanda de Potencia (MW)')
# plt.legend(title='Escenario')
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.xticks(df_demanda.index) # Asegura que todos los años del índice se muestren

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# Tabla No. 3-26. Proyección de la demanda de energía en bornes de generación – Hipótesis No. 2

# %%
# import pandas as pd

# # Datos extraídos de la tabla
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda Tendencial (GWh)': [28.824, 29.872, 31.090, 32.378, 33.447, 34.826, 36.383, 38.042, 39.651, 41.334],
#     'Demanda Caso Base (GWh)': [30.190, 32.157, 35.569, 38.392, 40.502, 42.195, 43.989, 46.084, 48.290, 50.544],
#     'Crecimiento Tendencial (%)': [3.0, 3.6, 4.1, 4.1, 3.3, 4.1, 4.5, 4.6, 4.2, 4.2],
#     'Crecimiento Caso Base (%)': [7.9, 6.5, 10.6, 7.9, 5.5, 4.2, 4.3, 4.8, 4.8, 4.7]
# }

# # Crear el DataFrame
# df = pd.DataFrame(data)

# # Mostrar el DataFrame (opcional)
# print("DataFrame de Proyección de Demanda de Energía:")
# print(df)

# %%
# import matplotlib.pyplot as plt

# # Generar el gráfico de líneas de la demanda de energía
# plt.figure(figsize=(10, 6))

# # Trazar las series de demanda (GWh)
# plt.plot(df['Año'], df['Demanda Tendencial (GWh)'], marker='o', label='Demanda Tendencial (GWh)')
# plt.plot(df['Año'], df['Demanda Caso Base (GWh)'], marker='s', label='Demanda Caso Base (GWh)')

# # Configurar el título y las etiquetas de los ejes
# plt.title('Proyección de la Demanda de Energía (GWh) 2023-2032')
# plt.xlabel('Año')
# plt.ylabel('Demanda de Energía (GWh)')

# # Configurar los ticks del eje X para mostrar todos los años
# plt.xticks(df['Año'], rotation=45)

# # Añadir la leyenda y la cuadrícula
# plt.legend(title='Escenario de Demanda')
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# # Nota: También se podría generar un gráfico de barras o líneas para comparar las tasas de crecimiento.

# %% [markdown]
# Tabla No. 3-27. Proyección de la demanda de potencia en bornes de generación - Hipótesis No. 2

# %%
# import pandas as pd

# # Datos extraídos de la tabla de la imagen
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda_Potencia_Tendencial (MW)': [4728, 4852, 5021, 5206, 5350, 5550, 5783, 6034, 6272, 6523],
#     'Demanda_Potencia_Caso_Base (MW)': [4891, 5175, 5861, 6317, 6632, 6863, 7128, 7465, 7808, 8126],
#     'Tasa_Crecimiento_Tendencial (%)': [7.7, 2.6, 3.5, 3.7, 2.8, 3.7, 4.2, 4.3, 4.0, 4.0],
#     'Tasa_Crecimiento_Caso_Base (%)': [11.5, 5.8, 13.2, 7.8, 5.0, 3.5, 3.9, 4.7, 4.6, 4.1]
# }

# df = pd.DataFrame(data)

# # Convertir la columna 'Año' a tipo entero y establecerla como índice
# df['Año'] = df['Año'].astype(int)
# df = df.set_index('Año')

# print("DataFrame de Proyección de Demanda de Potencia:")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # ... (Bloque de código del Paso 3 para crear el DataFrame) ...

# # Datos extraídos de la tabla de la imagen
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Demanda_Potencia_Tendencial (MW)': [4728, 4852, 5021, 5206, 5350, 5550, 5783, 6034, 6272, 6523],
#     'Demanda_Potencia_Caso_Base (MW)': [4891, 5175, 5861, 6317, 6632, 6863, 7128, 7465, 7808, 8126],
#     'Tasa_Crecimiento_Tendencial (%)': [7.7, 2.6, 3.5, 3.7, 2.8, 3.7, 4.2, 4.3, 4.0, 4.0],
#     'Tasa_Crecimiento_Caso_Base (%)': [11.5, 5.8, 13.2, 7.8, 5.0, 3.5, 3.9, 4.7, 4.6, 4.1]
# }

# df = pd.DataFrame(data)
# df['Año'] = df['Año'].astype(int)
# df = df.set_index('Año')

# # Generar el gráfico de líneas para la Demanda de Potencia
# plt.figure(figsize=(10, 6))

# # Seleccionar las columnas a graficar
# df[['Demanda_Potencia_Tendencial (MW)', 'Demanda_Potencia_Caso_Base (MW)']].plot(
#     kind='line',
#     marker='o',
#     ax=plt.gca()
# )

# # Configurar el gráfico
# plt.title('Proyección de la Demanda de Potencia (MW) 2023-2032', fontsize=14)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Demanda de Potencia (MW)', fontsize=12)
# plt.xticks(df.index) # Asegurar que todos los años se muestren
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.legend(title='Escenario')
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# Tabla No. 3-28. Cargas singulares de Industrias Básicas (MW)

# %%
# import pandas as pd

# # Datos extraídos de la tabla (el '-' se interpreta como 0)
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Acero (MW)': [0, 0, 0, 100, 200, 320, 320, 320, 320, 320],
#     'Cobre (MW)': [0, 0, 0, 70, 80, 90, 90, 90, 90, 90],
#     'Aluminio (MW)': [0, 0, 0, 0, 284, 850, 850, 850, 850, 850],
#     'Forestal (MW)': [0, 0, 0, 0, 0, 27, 53, 80, 80, 80],
#     'Total (MW)': [0, 0, 0, 170, 564, 1287, 1313, 1340, 1340, 1340]
# }

# df = pd.DataFrame(data)

# # Convertir la columna 'Año' a tipo entero y establecerla como índice
# df['Año'] = df['Año'].astype(int)
# df = df.set_index('Año')

# print("DataFrame de Cargas Singulares de Industrias Básicas (MW):")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # ... (Bloque de código del Paso 3 para crear el DataFrame) ...

# # Datos extraídos de la tabla (el '-' se interpreta como 0)
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Acero (MW)': [0, 0, 0, 100, 200, 320, 320, 320, 320, 320],
#     'Cobre (MW)': [0, 0, 0, 70, 80, 90, 90, 90, 90, 90],
#     'Aluminio (MW)': [0, 0, 0, 0, 284, 850, 850, 850, 850, 850],
#     'Forestal (MW)': [0, 0, 0, 0, 0, 27, 53, 80, 80, 80],
#     'Total (MW)': [0, 0, 0, 170, 564, 1287, 1313, 1340, 1340, 1340]
# }

# df = pd.DataFrame(data)
# df['Año'] = df['Año'].astype(int)
# df = df.set_index('Año')

# # Columnas a apilar (excluir la columna Total ya que es la suma de las otras)
# cols_to_plot = ['Acero (MW)', 'Cobre (MW)', 'Aluminio (MW)', 'Forestal (MW)']

# # Generar el gráfico de barras apiladas
# plt.figure(figsize=(12, 7))

# df[cols_to_plot].plot(
#     kind='bar',
#     stacked=True,
#     ax=plt.gca(),
#     colormap='viridis'  # Usar un mapa de color para diferenciar industrias
# )

# # Configurar el gráfico
# plt.title('Cargas Singulares de Industrias Básicas por Año (MW)', fontsize=16)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Carga Singular (MW)', fontsize=12)
# plt.xticks(rotation=45) # Rotar etiquetas para mejor legibilidad
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.legend(title='Industria', loc='upper left')
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()

# %% [markdown]
# Tabla No. 3-29. Consumo energético dado por las cargas singulares de industrias básicas (GWh)

# %%
# import pandas as pd

# # Datos extraídos de la tabla (el '-' se interpreta como 0)
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Acero (GWh)': [0, 0, 0, 491, 982, 1576, 1571, 1571, 1571, 1571],
#     'Cobre (GWh)': [0, 0, 0, 131, 262, 393, 392, 392, 392, 392],
#     'Aluminio (GWh)': [0, 0, 0, 0, 521, 595, 672, 670, 670, 670],
#     'Forestal (GWh)': [0, 0, 0, 0, 0, 937, 2798, 2798, 2798, 2798],
#     'Total (GWh)': [0, 0, 0, 622, 1765, 3501, 5433, 5432, 5432, 5432]
# }

# df = pd.DataFrame(data)

# # Convertir la columna 'Año' a tipo entero y establecerla como índice
# df['Año'] = df['Año'].astype(int)
# df = df.set_index('Año')

# print("DataFrame de Consumo Energético de Industrias Básicas (GWh):")
# print(df)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # ... (Bloque de código del Paso 3 para crear el DataFrame) ...

# # Datos extraídos de la tabla (el '-' se interpreta como 0)
# data = {
#     'Año': [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
#     'Acero (GWh)': [0, 0, 0, 491, 982, 1576, 1571, 1571, 1571, 1571],
#     'Cobre (GWh)': [0, 0, 0, 131, 262, 393, 392, 392, 392, 392],
#     'Aluminio (GWh)': [0, 0, 0, 0, 521, 595, 672, 670, 670, 670],
#     'Forestal (GWh)': [0, 0, 0, 0, 0, 937, 2798, 2798, 2798, 2798],
#     'Total (GWh)': [0, 0, 0, 622, 1765, 3501, 5433, 5432, 5432, 5432]
# }

# df = pd.DataFrame(data)
# df['Año'] = df['Año'].astype(int)
# df = df.set_index('Año')

# # Columnas a apilar (excluir la columna Total)
# cols_to_plot = ['Acero (GWh)', 'Cobre (GWh)', 'Aluminio (GWh)', 'Forestal (GWh)']

# # Generar el gráfico de barras apiladas
# plt.figure(figsize=(12, 7))

# df[cols_to_plot].plot(
#     kind='bar',
#     stacked=True,
#     ax=plt.gca(),
#     colormap='Set1' # Usar un mapa de color para diferenciar industrias
# )

# # Configurar el gráfico
# plt.title('Consumo Energético de Industrias Básicas por Año (GWh)', fontsize=16)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Consumo Energético (GWh)', fontsize=12)
# plt.xticks(rotation=45) # Rotar etiquetas para mejor legibilidad
# plt.grid(axis='y', linestyle='--', alpha=0.6)
# plt.legend(title='Industria', loc='upper left')
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()
