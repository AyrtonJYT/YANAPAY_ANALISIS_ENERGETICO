# %% [markdown]
# <a href="https://colab.research.google.com/github/AyrtonJYT/YANAPAY_ANALISIS_ENERGETICO/blob/main/Organized.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# I. Demanda Anual Proyectada (Potencia y Energía)

# %% [markdown]
# PME 2009-2020: Proyección de la demanda en bornes de generador (Tabla 5.11)

# %%
data_proyeccion_bornes_2009 = {
    'Año': [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
    'Potencia_Menor': [2883, 2909, 2933, 3354, 3477, 3601, 3839, 4110, 4371, 4626, 4849, 5037],
    'Potencia_Medio': [2909, 3076, 3304, 3455, 3610, 3768, 4044, 4354, 4658, 4960, 5232, 5473],
    'Potencia_Mayor': [2933, 3121, 3376, 3558, 3746, 3940, 4253, 4605, 4953, 5302, 5625, 5919],
    'Energia_Menor': [16992, 18075, 19539, 20327, 21134, 21944, 23500, 25182, 26808, 28402, 29807, 30996],
    'Energia_Medio': [17148, 18449, 20097, 21076, 22082, 23107, 24897, 26830, 28726, 30611, 32328, 33852],
    'Energia_Mayor': [17319, 18797, 20617, 21783, 22991, 24237, 26265, 28455, 30628, 32812, 34849, 36718]
}
df_proyeccion = pd.DataFrame(data_proyeccion_bornes_2009).set_index('Año')
df_proyeccion.columns = ['Potencia Menor (MW)', 'Potencia Medio (MW)', 'Potencia Mayor (MW)', 'Energía Menor (GWh)', 'Energía Medio (GWh)', 'Energía Mayor (GWh)']

# --- Código para generar el Plot ---

# Selecciona solo las columnas de Demanda de Energía para el gráfico
df_plot = df_proyeccion[['Energía Menor (GWh)', 'Energía Medio (GWh)', 'Energía Mayor (GWh)']]

plt.figure(figsize=(10, 6))

# Genera el gráfico de líneas
df_plot.plot(ax=plt.gca())

# Configuración del gráfico
plt.title('Proyección de la Demanda de Energía (GWh) por Escenario', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Demanda de Energía (GWh)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Escenario', loc='upper left')
plt.xticks(df_plot.index[::2]) # Muestra etiquetas de año cada dos puntos
plt.tight_layout() # Ajusta el diseño para que no se corten las etiquetas

# Muestra el gráfico
plt.show()

# %% [markdown]
# PME 2009-2020: Proyección anual energía y potencia (Escenario Medio) (Tabla 5.8)

# %%
data = {
    'Año': [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
    'Energia': [16205, 17453, 19032, 19980, 20956, 21952, 23677, 25542, 27376, 29203, 30873, 32363],
    'Potencia': [2751, 2911, 3130, 3276, 3426, 3579, 3844, 4143, 4435, 4727, 4991, 5224]
}
df_proyeccion_medio = pd.DataFrame(data).set_index('Año')
df_proyeccion_medio.columns = ['Energía (GWh)', 'Potencia (MW)']


plt.figure(figsize=(10, 6))

# Subplot para Energía (GWh)
ax1 = plt.gca()
df_proyeccion_medio['Energía (GWh)'].plot(ax=ax1, marker='o', color='tab:blue', label='Energía (GWh)')
ax1.set_ylabel('Energía (GWh)', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Crear un segundo eje Y para Potencia (MW)
ax2 = ax1.twinx()
df_proyeccion_medio['Potencia (MW)'].plot(ax=ax2, marker='s', color='tab:red', linestyle='--', label='Potencia (MW)')
ax2.set_ylabel('Potencia (MW)', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Configuración del gráfico
plt.title('Proyección Anual de Energía y Potencia Máxima (Escenario Medio)', fontsize=14)
ax1.set_xlabel('Año', fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.7)

# Unir las leyendas de ambos ejes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Muestra el gráfico
plt.show()

# %% [markdown]
# Plan Maestro Energético 2012-2021

# %% [markdown]
# PME 2012-2021: Proyección de la Demanda en Bornes de Generación (Tabla 4.13)

# %%
data = {
    'Año': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],

    # Demanda de Potencia (MW)
    'Demanda Potencia - Menor (MW)': [3.034, 3.177, 3.474, 3.748, 3.974, 4.457, 4.766, 4.980, 5.179, 5.357, 5.513],
    'Demanda Potencia - Medio (MW)': [3.052, 3.226, 3.548, 3.848, 4.108, 4.639, 4.992, 5.247, 5.489, 5.714, 5.920],
    'Demanda Potencia - Mayor (MW)': [3.069, 3.277, 3.629, 3.965, 4.262, 4.845, 5.247, 5.545, 5.834, 6.110, 6.369],

    # Demanda de Energía (GWh)
    'Demanda Energía - Menor (GWh)': [18.497, 19.329, 20.538, 22.388, 23.997, 27.623, 29.821, 31.130, 32.383, 33.522, 34.539],
    'Demanda Energía - Medio (GWh)': [18.645, 19.663, 21.056, 23.133, 24.965, 28.930, 31.422, 32.989, 34.516, 35.958, 37.299],
    'Demanda Energía - Mayor (GWh)': [18.831, 20.052, 21.617, 23.925, 25.997, 30.328, 33.138, 34.985, 36.808, 38.579, 40.270]
}

df = pd.DataFrame(data)

# 3. Configuración y Generación del Gráfico de Líneas para Demanda de Energía
plt.figure(figsize=(12, 7))

# Trazar las 3 series de Demanda de Energía (GWh)
plt.plot(df['Año'], df['Demanda Energía - Menor (GWh)'], marker='o', linestyle=':', color='skyblue', label='Escenario Menor')
plt.plot(df['Año'], df['Demanda Energía - Medio (GWh)'], marker='s', linestyle='-', color='blue', linewidth=2, label='Escenario Medio')
plt.plot(df['Año'], df['Demanda Energía - Mayor (GWh)'], marker='^', linestyle='--', color='darkblue', label='Escenario Mayor')

# Configuración de etiquetas, título y leyenda
plt.title('Proyección de la Demanda de Energía (GWh) en Bornes de Generación (2011-2021)')
plt.xlabel('Año')
plt.ylabel('Demanda de Energía (GWh)')
plt.legend(title='Escenario de Proyección', loc='upper left')
plt.grid(True, linestyle=':', alpha=0.7)
plt.xticks(df['Año'].astype(int), rotation=45) # Asegura que se muestren todos los años

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# Plan Maestro Energético 2013-2022

# %% [markdown]
# PME 2013-2022: Proyección de Demanda de Energía (GWh) por Hipótesis (Escenario Menor, 2000-2032)

# %%
datos_proyeccion = {
    'Año': list(range(2013, 2033)),
    'Demanda Menor (GWh)': [
        20056, 20829, 23553, 28088, 34137, 35328, 36645, 37866, 38927, 39935,
        41052, 42204, 43393, 44631, 45909, 47219, 48571, 49968, 51193, 52682
    ],
    'Demanda Medio (GWh)': [
        20634, 21639, 24574, 29313, 35571, 36982, 38534, 40009, 41339, 42701,
        44205, 45773, 47408, 49126, 50920, 52783, 54728, 56759, 58665, 60882
    ],
    'Demanda Mayor (GWh)': [
        20867, 22106, 25339, 30436, 37106, 38967, 41016, 43035, 44963, 46913,
        49070, 51355, 53775, 56352, 59085, 61974, 65041, 68295, 71533, 75204
    ]
}


df_proyeccion = pd.DataFrame(datos_proyeccion)
df_proyeccion.set_index('Año', inplace=True)



# Crear la figura y los ejes
plt.figure(figsize=(12, 6))

# Trazar las líneas para cada escenario
plt.plot(df_proyeccion.index, df_proyeccion['Demanda Menor (GWh)'], label='Crecimiento Menor', marker='^', linestyle='-', color='red')
plt.plot(df_proyeccion.index, df_proyeccion['Demanda Medio (GWh)'], label='Crecimiento Medio', marker='o', linestyle='-', color='blue')
plt.plot(df_proyeccion.index, df_proyeccion['Demanda Mayor (GWh)'], label='Crecimiento Mayor', marker='s', linestyle='-', color='green')

# Personalización del gráfico
plt.title('Proyección de la Demanda Anual de Energía Eléctrica (2013-2032)', fontsize=16)
plt.ylabel('Demanda de Energía (GWh)', fontsize=12)
plt.xlabel('Año', fontsize=12)
plt.xticks(df_proyeccion.index[::2], rotation=45) # Mostrar años cada dos años
plt.legend(title='Escenario de Crecimiento')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plan Maestro Energético 2016-2025

# %% [markdown]
# PME 2016-2025: Caso Base Potencia (Tabla 1.1) y Energía (Tabla 1.2)

# %%
# --- Datos extraídos de la tabla ---
data = {
    'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
    'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
    'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
    'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861],
    'Crecimiento (%) - Medio': [0.0, 2.2, 7.6, 7.1, 6.5, 6.1, 5.8, 5.2, 4.1, 4.5]
}

# Creación del DataFrame
df_energia = pd.DataFrame(data)

# Aplicar las transformaciones que tenías
df_energia['Demanda (GWh) - Menor'] = df_energia['Demanda (GWh) - Menor'] * 1000
df_energia['Demanda (GWh) - Medio'] = df_energia['Demanda (GWh) - Medio'] * 1000
df_energia['Demanda (GWh) - Mayor'] = df_energia['Demanda (GWh) - Mayor'] * 1000
df_energia.set_index('Año', inplace=True)

# Mostrar el DataFrame (opcional)
print("DataFrame de Previsión de la Demanda Anual de Energía Eléctrica:")
print(df_energia)
print("-" * 50)


# --- Código para Plotear ---

# 1. Crear la figura y el primer eje (para la Demanda)
fig, ax1 = plt.subplots(figsize=(10, 6)) # figsize para mejor visualización

# 2. Graficar las series de Demanda en el eje principal (ax1)
color_demanda_menor = 'tab:blue'
color_demanda_medio = 'tab:orange'
color_demanda_mayor = 'tab:green'

ax1.plot(df_energia.index, df_energia['Demanda (GWh) - Menor'], color=color_demanda_menor, linestyle='--', marker='o', label='Demanda Menor')
ax1.plot(df_energia.index, df_energia['Demanda (GWh) - Medio'], color=color_demanda_medio, linestyle='-', marker='o', label='Demanda Medio')
ax1.plot(df_energia.index, df_energia['Demanda (GWh) - Mayor'], color=color_demanda_mayor, linestyle='--', marker='o', label='Demanda Mayor')

# Etiquetas y ticks para el eje principal (Demanda)
ax1.set_xlabel('Año')
ax1.set_ylabel('Demanda (MWh)', color='black') # La unidad cambia a MWh al multiplicar por 1000
ax1.tick_params(axis='y') # color='black' no es necesario por defecto

# Títulos del gráfico
plt.title('Previsión de Demanda de Energía Eléctrica y Crecimiento Anual')



# 5. Configuración final
# Asegurar que el eje X muestre los años como enteros
ax1.set_xticks(df_energia.index)
ax1.grid(True, linestyle='--', alpha=0.6) # Agregar una rejilla

# Combinar las leyendas de ambos ejes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

# Mostrar el gráfico
plt.show()
# Out:
# DataFrame de Previsión de la Demanda Anual de Energía Eléctrica:
#       Demanda (GWh) - Menor  Demanda (GWh) - Medio  Demanda (GWh) - Mayor  \
# Año
# 2016                23518.0                23518.0                23518.0
# 2017                23790.0                24040.0                24262.0
# 2018                25357.0                25878.0                26342.0
# 2019                26917.0                27710.0                28438.0
# 2020                28427.0                29523.0                30540.0
# 2021                29913.0                31328.0                32665.0
# 2022                31368.0                33144.0                34835.0
# 2023                32700.0                34862.0                36937.0
# 2024                33721.0                36293.0                38787.0
# 2025                34904.0                37912.0                40861.0
#
#       Crecimiento (%) - Medio
# Año
# 2016                      0.0
# ...

# %%
data = {
    'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
    'Demanda (GWh) - Menor': [23.518, 23.790, 25.357, 26.917, 28.427, 29.913, 31.368, 32.700, 33.721, 34.904],
    'Demanda (GWh) - Medio': [23.518, 24.040, 25.878, 27.710, 29.523, 31.328, 33.144, 34.862, 36.293, 37.912],
    'Demanda (GWh) - Mayor': [23.518, 24.262, 26.342, 28.438, 30.540, 32.665, 34.835, 36.937, 38.787, 40.861],
}

df_energia = pd.DataFrame(data)
df_energia.set_index('Año', inplace=True)

# Generación del gráfico de líneas para los tres escenarios de demanda
plt.figure(figsize=(12, 6))

# Trazado de las líneas
plt.plot(df_energia.index, df_energia['Demanda (GWh) - Menor'], label='Escenario Menor', marker='s', linestyle='--')
plt.plot(df_energia.index, df_energia['Demanda (GWh) - Medio'], label='Escenario Medio', marker='o', linestyle='-')
plt.plot(df_energia.index, df_energia['Demanda (GWh) - Mayor'], label='Escenario Mayor', marker='^', linestyle='-.')

# Añadir título y etiquetas
plt.title('Previsión de la Demanda Anual de Energía Eléctrica (2016-2025)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Demanda de Energía (GWh)', fontsize=12)

# Configuración del eje X (mostrar todos los años)
plt.xticks(df_energia.index)

# Añadir leyenda y cuadrícula
plt.legend(title='Escenario de Previsión')
plt.grid(True, linestyle=':', alpha=0.6)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Datos extraídos y DataFrame (mismo del Paso 3)
data = {
    'Año': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
    'Demanda (MW) - Menor': [3653, 3948, 4211, 4481, 4691, 4895, 5115, 5724, 6252, 6684],
    'Demanda (MW) - Medio': [3653, 3988, 4295, 4610, 4867, 5120, 5396, 6064, 6653, 7144],
    'Demanda (MW) - Mayor': [3653, 4022, 4364, 4718, 5017, 5316, 5642, 6363, 7010, 7560],
}

df_potencia_hipotesis5 = pd.DataFrame(data)
df_potencia_hipotesis5.set_index('Año', inplace=True)

# Generación del gráfico de líneas para los tres escenarios de demanda
plt.figure(figsize=(12, 6))

# Trazado de las líneas
plt.plot(df_potencia_hipotesis5.index, df_potencia_hipotesis5['Demanda (MW) - Menor'], label='Escenario Menor', marker='o', linestyle='--')
plt.plot(df_potencia_hipotesis5.index, df_potencia_hipotesis5['Demanda (MW) - Medio'], label='Escenario Medio', marker='o', linestyle='-')
plt.plot(df_potencia_hipotesis5.index, df_potencia_hipotesis5['Demanda (MW) - Mayor'], label='Escenario Mayor', marker='o', linestyle='-.')

# Añadir título y etiquetas
plt.title('Previsión de la Demanda Anual de Potencia Eléctrica (Hipótesis No. 5: 2016-2025)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Demanda de Potencia (MW)', fontsize=12)

# Configuración del eje X (mostrar todos los años)
plt.xticks(df_potencia_hipotesis5.index)

# Añadir leyenda y cuadrícula
plt.legend(title='Escenario de Previsión')
plt.grid(True, linestyle=':', alpha=0.6)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# Plan Maestro Energético 2018-2027

# %% [markdown]
# PME 2018-2027: Previsión Demanda Potencia en Bornes (Hipótesis No. 2, 2018-2027) (Tabla 1.4)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos extraídos (Mismo código del paso 3)
datos_prevision = {
    'Año': [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027],
    'Demanda Potencia (MW) - Menor': [3.933, 4.185, 4.785, 5.103, 5.338, 5.514, 5.681, 5.860, 6.024, 6.199],
    'Demanda Potencia (MW) - Medio': [3.933, 4.295, 4.958, 5.346, 5.661, 5.924, 6.186, 6.468, 6.739, 7.028],
    'Demanda Potencia (MW) - Mayor': [3.933, 4.385, 5.108, 5.562, 5.954, 6.304, 6.665, 7.058, 7.453, 7.883],
    'Tasa Crecimiento (%) - Menor': ['-', 6.4, 14.3, 6.7, 4.6, 3.3, 3.0, 3.1, 2.8, 2.9],
    'Tasa Crecimiento (%) - Medio': ['-', 9.2, 15.4, 7.8, 5.9, 4.7, 4.4, 4.6, 4.2, 4.3],
    'Tasa Crecimiento (%) - Mayor': ['-', 11.5, 16.5, 8.9, 7.0, 5.9, 5.7, 5.9, 5.6, 5.8]
}

df_prevision = pd.DataFrame(datos_prevision)
df_prevision['Año'] = df_prevision['Año'].astype(int)

# Establecer 'Año' como índice para el ploteo de series de tiempo
df_plot = df_prevision.set_index('Año')

# Columnas de demanda de potencia a graficar
columnas_demanda = [
    'Demanda Potencia (MW) - Menor',
    'Demanda Potencia (MW) - Medio',
    'Demanda Potencia (MW) - Mayor'
]

# Generación del Gráfico de Líneas
plt.figure(figsize=(12, 7))

# Gráfico de líneas
df_plot[columnas_demanda].plot(
    kind='line',
    ax=plt.gca(),
    marker='o',
    linestyle='-',
    linewidth=2,
    markersize=5
)

# Configuración de Título y Ejes
plt.title('Previsión de la Demanda Anual de Potencia (MW) 2018-2027', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Demanda de Potencia (MW)', fontsize=12)

# Configuración de la Leyenda
plt.legend(
    ['Escenario Menor', 'Escenario Medio', 'Escenario Mayor'],
    title='Escenario de Previsión',
    loc='upper left'
)

# Configuración del Eje X: Mostrar todos los años
plt.xticks(df_plot.index, rotation=45)

# Añadir una cuadrícula para facilitar la lectura
plt.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño para evitar que las etiquetas se corten
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos de la tabla de previsión de la demanda de energía (Mismo código del paso 3)
datos_prevision_energia = {
    'Año': [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027],
    'Demanda Energía (GWh) - Menor': [24.062, 25.936, 28.878, 31.394, 33.090, 34.396, 35.581, 36.740, 37.894, 39.088],
    'Demanda Energía (GWh) - Medio': [24.062, 26.675, 30.040, 33.023, 35.255, 37.148, 38.976, 40.837, 42.723, 44.715],
    'Demanda Energía (GWh) - Mayor': [24.062, 27.308, 31.078, 34.523, 37.291, 39.793, 42.311, 44.953, 47.715, 50.696],
    'Tasa Crecimiento (%) - Menor': ['-', 7.8, 11.3, 8.7, 5.4, 3.9, 3.4, 3.3, 3.1, 3.2],
    'Tasa Crecimiento (%) - Medio': ['-', 10.9, 12.6, 9.9, 6.8, 5.4, 4.9, 4.8, 4.6, 4.7],
    'Tasa Crecimiento (%) - Mayor': ['-', 13.5, 13.8, 11.1, 8.0, 6.7, 6.3, 6.2, 6.1, 6.2]
}

df_prevision_energia = pd.DataFrame(datos_prevision_energia)
df_prevision_energia['Año'] = df_prevision_energia['Año'].astype(int)
df_plot = df_prevision_energia.set_index('Año')

# Columnas de demanda de energía a graficar
columnas_demanda = [
    'Demanda Energía (GWh) - Menor',
    'Demanda Energía (GWh) - Medio',
    'Demanda Energía (GWh) - Mayor'
]

# Generación del Gráfico de Líneas
plt.figure(figsize=(12, 7))

# Gráfico de líneas
df_plot[columnas_demanda].plot(
    kind='line',
    ax=plt.gca(),
    marker='o',
    linestyle='-',
    linewidth=2,
    markersize=5
)

# Configuración de Título y Ejes
plt.title('Previsión de la Demanda Anual de Energía (GWh) 2018-2027', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Demanda de Energía (GWh)', fontsize=12)

# Configuración de la Leyenda
plt.legend(
    ['Escenario Menor', 'Escenario Medio', 'Escenario Mayor'],
    title='Escenario de Previsión',
    loc='upper left'
)

# Configuración del Eje X: Mostrar todos los años
plt.xticks(df_plot.index, rotation=45)

# Añadir una cuadrícula para facilitar la lectura
plt.grid(True, linestyle='--', alpha=0.7)

# Ajustar el diseño para evitar que las etiquetas se corten
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Plan Maestro Energético 2023-2032

# %% [markdown]
# PME 2023-2032: Proyección Demanda Energía Bornes (Hipótesis 2, 2022-2032) (Figura 1.7)

# %%
data = {
    'Año': [2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
    'Demanda Tendencial (GWh)': [28.500, 29.500, 30.000, 31.500, 32.500, 34.000, 35.000, 37.000, 38.500, 40.000, 41.334],
    'Demanda Base (GWh)': [28.500, 30.000, 32.250, 35.500, 38.500, 40.500, 42.000, 44.000, 46.500, 48.500, 50.544]
}
df = pd.DataFrame(data)
# ----------------------------------------

# Configuración del plot
plt.figure(figsize=(10, 6))

# Gráfico de Líneas para Demanda Tendencial
plt.plot(df['Año'], df['Demanda Tendencial (GWh)'],
         marker='o', linestyle='-', color='#9FBED9', label='Tendencial')

# Gráfico de Líneas para Demanda Base
plt.plot(df['Año'], df['Demanda Base (GWh)'],
         marker='o', linestyle='-', color='#314777', label='Base')

# Etiquetas, Título y Leyenda
plt.title('Proyección de la demanda de energía anual (GWh) 2022-2032')
plt.xlabel('Año')
plt.ylabel('Energía [GWh]')
plt.legend(loc='lower center', ncol=2)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(df['Año']) # Asegurar que se muestren todos los años

# Agregar los valores finales
plt.annotate(f"{df['Demanda Tendencial (GWh)'].iloc[-1]:.3f}",
             (df['Año'].iloc[-1], df['Demanda Tendencial (GWh)'].iloc[-1]),
             textcoords="offset points", xytext=(5, -5), ha='left')
plt.annotate(f"{df['Demanda Base (GWh)'].iloc[-1]:.3f}",
             (df['Año'].iloc[-1], df['Demanda Base (GWh)'].iloc[-1]),
             textcoords="offset points", xytext=(5, 5), ha='left', fontweight='bold')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
data = {
    'Año': [2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032],
    'Potencia Máxima Tendencial (MW)': [4.350, 4.850, 4.900, 5.000, 5.200, 5.350, 5.500, 5.750, 6.000, 6.300, 6.523],
    'Potencia Máxima Base (MW)': [4.350, 5.000, 5.250, 5.850, 6.300, 6.600, 6.850, 7.150, 7.450, 7.850, 8.126]
}
df = pd.DataFrame(data)
# ----------------------------------------

# Configuración del plot
plt.figure(figsize=(10, 6))

# Gráfico de Líneas para Demanda Tendencial
plt.plot(df['Año'], df['Potencia Máxima Tendencial (MW)'],
         marker='o', linestyle='-', color='#9FBED9', label='Tendencial')

# Gráfico de Líneas para Demanda Base
plt.plot(df['Año'], df['Potencia Máxima Base (MW)'],
         marker='o', linestyle='-', color='#314777', label='Base')

# Etiquetas, Título y Leyenda
plt.title('Proyección de la Demanda de Potencia Máxima Anual (MW) 2022-2032')
plt.xlabel('Año')
plt.ylabel('Potencia [MW]')
plt.legend(loc='lower center', ncol=2)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(df['Año']) # Asegurar que se muestren todos los años

# Agregar los valores finales
plt.annotate(f"{df['Potencia Máxima Tendencial (MW)'].iloc[-1]:.3f}",
             (df['Año'].iloc[-1], df['Potencia Máxima Tendencial (MW)'].iloc[-1]),
             textcoords="offset points", xytext=(5, -5), ha='left')
plt.annotate(f"{df['Potencia Máxima Base (MW)'].iloc[-1]:.3f}",
             (df['Año'].iloc[-1], df['Potencia Máxima Base (MW)'].iloc[-1]),
             textcoords="offset points", xytext=(5, 5), ha='left', fontweight='bold')

# Mostrar el gráfico
plt.tight_layout()
plt.show()
