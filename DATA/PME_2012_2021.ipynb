# %% [markdown]
# <a href="https://colab.research.google.com/github/AyrtonJYT/YANAPAY_ANALISIS_ENERGETICO/blob/main/DATA/PME_2012_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2012-2021

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Tabla 4.2
# CONSUMO DE ENERGÍA ELÉCTRICA Y CRECIMIENTO EN EL PERÍODO 2001-2010

# %%
# # 1. Datos completos extraídos de la tabla (Consumo en GWh y Variación Anual %)
# data = {
#     'Año': [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011],
#     'Consumo Residencial (GWh)': [2.897, 3.093, 3.248, 3.516, 3.677, 3.885, 4.103, 4.372, 4.687, 5.101, 5.288],
#     'Variación Residencial (%)': [4.4, 6.8, 5.0, 8.3, 4.6, 5.7, 5.6, 6.6, 7.2, 8.8, 3.7],

#     'Consumo Comercial (GWh)': [1.412, 1.566, 1.659, 1.807, 1.947, 2.116, 2.231, 2.429, 2.581, 2.663, 2.921],
#     'Variación Comercial (%)': [5.0, 10.9, 5.9, 9.0, 7.7, 8.7, 5.4, 8.9, 6.3, 3.2, 9.7],

#     'Consumo Industrial (GWh)': [2.399, 2.423, 2.562, 2.743, 2.958, 3.296, 3.617, 3.880, 3.994, 4.416, 4.741],
#     'Variación Industrial (%)': [9.5, 1.0, 5.7, 7.0, 7.8, 11.4, 9.7, 7.3, 3.0, 10.6, 7.3],

#     'Consumo Alumb. Público y Otros (GWh)': [1.421, 1.476, 1.511, 1.506, 1.593, 1.698, 1.793, 1.834, 1.979, 1.867, 2.120],
#     'Variación Alumb. Público y Otros (%)': [6.8, 3.9, 2.3, -0.3, 5.8, 6.6, 5.6, 2.3, 7.9, -5.7, 13.6],

#     'Consumo Total (GWh)': [8.129, 8.559, 8.980, 9.572, 10.174, 10.996, 11.744, 12.516, 13.241, 14.047, 15.070],
#     'Variación Total (%)': [3.7, 5.3, 4.9, 6.6, 6.3, 8.1, 6.8, 6.6, 5.8, 6.1, 7.3]
# }

# # 2. Creación del DataFrame con todos los datos
# df = pd.DataFrame(data)

# # Muestra las primeras filas del DataFrame (Verificación)
# print("DataFrame Completo de Consumo de Energía Eléctrica (Primeras 5 filas):")
# print(df.head())
# print("-" * 150) # Separador visual

# # 3. Configuración y Generación del Gráfico de Líneas (Comparación Sectorial)
# plt.figure(figsize=(12, 7))

# # Trazar las series de consumo de los 4 sectores principales
# plt.plot(df['Año'], df['Consumo Residencial (GWh)'], marker='o', label='Residencial')
# plt.plot(df['Año'], df['Consumo Comercial (GWh)'], marker='s', label='Comercial')
# plt.plot(df['Año'], df['Consumo Industrial (GWh)'], marker='^', label='Industrial')
# plt.plot(df['Año'], df['Consumo Alumb. Público y Otros (GWh)'], marker='d', label='Alumb. Público y Otros')

# # Configuración de etiquetas, título y leyenda
# plt.title('Consumo de Energía Eléctrica por Sector (GWh): Tendencias 2001-2011')
# plt.xlabel('Año')
# plt.ylabel('Consumo (GWh)')
# plt.legend(title='Sector', loc='upper left')
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.xticks(df['Año'].astype(int), rotation=45) # Asegura que se muestren todos los años

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()
# Out:
# DataFrame Completo de Consumo de Energía Eléctrica (Primeras 5 filas):
#     Año  Consumo Residencial (GWh)  Variación Residencial (%)  \
# 0  2001                      2.897                        4.4
# 1  2002                      3.093                        6.8
# 2  2003                      3.248                        5.0
# 3  2004                      3.516                        8.3
# 4  2005                      3.677                        4.6
#
#    Consumo Comercial (GWh)  Variación Comercial (%)  Consumo Industrial (GWh)  \
# 0                    1.412                      5.0                     2.399
# 1                    1.566                     10.9                     2.423
# 2                    1.659                      5.9                     2.562
# 3                    1.807                      9.0                     2.743
# 4                    1.947                      7.7                     2.958
#
# ...

# %% [markdown]
# #Tabla 4.9
# Proyección de consumo de energía eléctrica facturada a clientes finales por sector (H3) para el período 2011-2021.

# %%
# # 1. Datos completos de la Proyección de Consumo de Energía Eléctrica (GWh)
# data = {
#     'Año': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
#     'Consumo Residencial (GWh)': [5.288, 5.497, 5.827, 6.298, 6.765, 7.268, 7.988, 8.703, 9.331, 9.895, 10.344],
#     'Consumo Comercial (GWh)': [2.921, 3.107, 3.310, 3.557, 4.006, 4.239, 4.488, 4.744, 5.003, 5.260, 5.527],
#     'Consumo Industrial (GWh)': [4.742, 5.045, 5.716, 6.890, 7.556, 10.241, 11.414, 11.777, 12.171, 12.560, 12.958],
#     'Consumo Alumb. Público y Otros (GWh)': [2.119, 2.618, 2.764, 2.915, 3.072, 3.227, 3.403, 3.586, 3.785, 3.982, 4.187],
#     'Consumo Total (GWh)': [15.070, 16.268, 17.616, 19.660, 21.399, 24.975, 27.293, 28.810, 30.290, 31.696, 33.015]
#     # Se omiten filas de composición y crecimiento promedio por ser metadatos de resumen, no series de tiempo.
# }

# # 2. Creación del DataFrame con unidades en los nombres de columna
# df = pd.DataFrame(data)

# # Muestra las primeras filas del DataFrame
# print("DataFrame de Proyección de Consumo de Energía Eléctrica (Primeras 5 filas):")
# print(df.head())
# print("-" * 100) # Separador visual

# # 3. Configuración y Generación del Gráfico de Líneas
# plt.figure(figsize=(6, 7))

# # Trazar el Consumo Total proyectado
# plt.plot(df['Año'], df['Consumo Total (GWh)'], marker='o', linestyle='-', color='darkred', linewidth=3, label='Consumo Total Proyectado')

# # Trazar el Consumo Industrial proyectado (el de mayor crecimiento)
# plt.plot(df['Año'], df['Consumo Industrial (GWh)'], marker='s', linestyle='--', color='teal', linewidth=2, label='Consumo Industrial Proyectado')

# # Configuración de etiquetas, título y leyenda
# plt.title('Proyección del Consumo de Energía Eléctrica (GWh) por Año (2011-2021)')
# plt.xlabel('Año')
# plt.ylabel('Consumo Proyectado (GWh)')
# plt.legend(title='Serie de Consumo', loc='upper left')
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.xticks(df['Año'].astype(int), rotation=45) # Asegura que se muestren todos los años en el eje X

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #Tabla 4.13
# PROYECCIÓN DE LA DEMANDA EN BORNES DE GENERACIÓN

# %%
# # 1. Datos completos de la Proyección de la Demanda en Bornes de Generación
# data = {
#     'Año': [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],

#     # Demanda de Potencia (MW)
#     'Demanda Potencia - Menor (MW)': [3.034, 3.177, 3.474, 3.748, 3.974, 4.457, 4.766, 4.980, 5.179, 5.357, 5.513],
#     'Demanda Potencia - Medio (MW)': [3.052, 3.226, 3.548, 3.848, 4.108, 4.639, 4.992, 5.247, 5.489, 5.714, 5.920],
#     'Demanda Potencia - Mayor (MW)': [3.069, 3.277, 3.629, 3.965, 4.262, 4.845, 5.247, 5.545, 5.834, 6.110, 6.369],

#     # Demanda de Energía (GWh)
#     'Demanda Energía - Menor (GWh)': [18.497, 19.329, 20.538, 22.388, 23.997, 27.623, 29.821, 31.130, 32.383, 33.522, 34.539],
#     'Demanda Energía - Medio (GWh)': [18.645, 19.663, 21.056, 23.133, 24.965, 28.930, 31.422, 32.989, 34.516, 35.958, 37.299],
#     'Demanda Energía - Mayor (GWh)': [18.831, 20.052, 21.617, 23.925, 25.997, 30.328, 33.138, 34.985, 36.808, 38.579, 40.270]
# }

# # 2. Creación del DataFrame con todos los datos
# df = pd.DataFrame(data)

# # Muestra las primeras filas del DataFrame (Verificación)
# print("DataFrame Completo de Proyección de Demanda (Primeras 5 filas):")
# print(df.head())
# print("-" * 150) # Separador visual

# # 3. Configuración y Generación del Gráfico de Líneas para Demanda de Energía
# plt.figure(figsize=(12, 7))

# # Trazar las 3 series de Demanda de Energía (GWh)
# plt.plot(df['Año'], df['Demanda Energía - Menor (GWh)'], marker='o', linestyle=':', color='skyblue', label='Escenario Menor')
# plt.plot(df['Año'], df['Demanda Energía - Medio (GWh)'], marker='s', linestyle='-', color='blue', linewidth=2, label='Escenario Medio')
# plt.plot(df['Año'], df['Demanda Energía - Mayor (GWh)'], marker='^', linestyle='--', color='darkblue', label='Escenario Mayor')

# # Configuración de etiquetas, título y leyenda
# plt.title('Proyección de la Demanda de Energía (GWh) en Bornes de Generación (2011-2021)')
# plt.xlabel('Año')
# plt.ylabel('Demanda de Energía (GWh)')
# plt.legend(title='Escenario de Proyección', loc='upper left')
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.xticks(df['Año'].astype(int), rotation=45) # Asegura que se muestren todos los años

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #Gráfico 4.3
# Tasa anual de variación del PIB y demanda de energía eléctrica (Histórico 1998-2011

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # 1. Datos extraídos de la Tasa Anual de Variación del PIB y Demanda de Energía Eléctrica
# data = {
#     'Año': [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011],
#     # Nombres de columna con la unidad de medida
#     'Variación Demanda Eléctrica (%)': [5.0, -6.0, 2.5, 3.8, 5.5, 4.9, 6.8, 6.2, 8.2, 7.0, 6.8, 6.0, 6.5, 7.2],
#     'Variación PIB (%)': [1.8, -5.3, 4.2, 4.7, 3.5, 3.4, 9.0, 5.8, 4.8, 2.0, 7.5, 0.3, 3.7, 8.0]
# }

# # 2. Creación del DataFrame
# df = pd.DataFrame(data)

# # Mostrar las primeras filas del DataFrame (Verificación)
# print("DataFrame: Tasa Anual de Variación (%) del PIB y Demanda (Primeras 5 filas):")
# print(df.head())
# print("-" * 100) # Separador visual

# # 3. Configuración y Generación del Gráfico de Líneas (Plot)
# plt.figure(figsize=(12, 6))

# # Trazar la serie de Demanda Eléctrica
# plt.plot(df['Año'], df['Variación Demanda Eléctrica (%)'], marker='D', linestyle='-', color='saddlebrown', label='Demanda Eléctrica (%)')

# # Trazar la serie del PIB
# plt.plot(df['Año'], df['Variación PIB (%)'], marker='s', linestyle='-', color='red', label='PIB (%)')

# # Configuración de etiquetas, título y leyenda
# plt.title('Tasa Anual de Variación del PIB y Demanda de Energía Eléctrica (1998-2011)')
# plt.xlabel('Año')
# plt.ylabel('Variación Anual (%)')
# plt.legend(loc='lower center', ncol=2, frameon=True)
# plt.grid(True, linestyle=':', alpha=0.6)
# # Asegura que los años sean tratados como categóricos o enteros en el eje X para mejor visualización
# plt.xticks(df['Año'].astype(int), rotation=45)

# # Mostrar el gráfico
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #Gráfico 4.6
# Histórico de demanda de energía mensual en puntos de entrega (2000-2011).

# %%
"OBTENER LOS PUNTOS CON MATHEMATICA "

# %% [markdown]
# #Gráfico 4.7
# Demanda de potencia máxima mensual en bornes de generador (2000-2011).

# %%
"OBTENER LOS PUNTOS CON MATHEMATICA "

# %% [markdown]
# #Tabla 2.13
# Porcentaje de pérdidas de energía en los sistemas de distribución para el período 1999–2010

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # 1. Datos de la tabla extraídos
# data = {
#     'Empresa/Categoría': [
#         'CNEL-Manabí', 'CNEL-Los Ríos', 'CNEL-Esmeraldas', 'CNEL-Milagro',
#         'CNEL-Guayas Los Ríos', 'CNEL-Sucumbíos', 'CNEL-El Oro', 'CNEL-Bolívar',
#         'CNEL-Sta. Elena', 'CNEL-Sto. Domingo', 'Total CNEL',
#         'Eléctrica de Guayaquil', 'E.E. Riobamba', 'E.E. Sur', 'E.E. Norte',
#         'E.E. Galápagos', 'E.E. Ambato', 'E.E. Cotopaxi', 'E.E. Quito',
#         'E.E. Centro Sur', 'E.E. Azogues', 'Total Empresas Eléctricas', 'Media Nacional'
#     ],
#     '1999 (%)': [
#         28.90, 25.87, 18.42, 29.07, 27.48, 28.10, 22.88, 22.10, 17.44, 18.94,
#         25.23, 23.88, 12.77, 15.68, 15.33, 11.69, 15.36, 12.44, 16.63, 7.11,
#         9.95, 18.87, 20.83
#     ],
#     '2000 (%)': [
#         30.25, 22.85, 22.14, 25.42, 32.18, 32.00, 27.31, 18.94, 22.13, 23.83,
#         27.54, 24.41, 16.27, 17.39, 18.45, 11.08, 14.66, 18.70, 16.44, 8.22,
#         12.66, 19.34, 21.89
#     ],
#     '2001 (%)': [
#         27.33, 25.87, 27.15, 34.84, 33.81, 32.53, 25.68, 16.83, 24.97, 24.84,
#         28.95, 24.71, 18.31, 15.02, 19.63, 11.35, 13.21, 16.20, 16.01, 11.39,
#         7.41, 19.32, 22.31
#     ],
#     '2002 (%)': [
#         28.99, 25.56, 26.45, 36.94, 39.39, 35.82, 25.74, 24.17, 25.09, 19.22,
#         30.32, 25.39, 17.38, 15.22, 17.34, 11.09, 14.97, 15.05, 15.04, 9.11,
#         7.38, 19.09, 22.51
#     ],
#     '2003 (%)': [
#         33.03, 28.45, 28.72, 34.96, 39.91, 37.57, 28.34, 22.76, 27.60, 20.67,
#         32.11, 24.27, 18.54, 14.67, 17.42, 10.39, 14.99, 18.42, 15.30, 8.18,
#         6.97, 18.74, 22.89
#     ],
#     '2004 (%)': [
#         35.24, 27.82, 29.67, 33.59, 38.23, 35.81, 29.75, 22.32, 30.55, 19.56,
#         32.48, 24.49, 16.67, 14.45, 16.19, 8.09, 16.00, 15.07, 15.27, 8.24,
#         7.58, 18.64, 23.01
#     ],
#     '2005 (%)': [
#         36.24, 30.27, 30.42, 34.42, 35.38, 38.07, 30.35, 18.34, 28.82, 18.46,
#         33.04, 24.91, 16.04, 13.86, 14.58, 7.84, 13.76, 12.28, 13.24, 9.42,
#         6.05, 17.94, 22.76
#     ],
#     '2006 (%)': [
#         39.53, 29.40, 32.17, 33.65, 34.92, 35.07, 29.05, 19.65, 23.73, 17.45,
#         32.67, 25.13, 16.51, 13.56, 13.91, 9.66, 13.59, 12.11, 11.12, 8.89,
#         5.01, 17.27, 22.25
#     ],
#     '2007 (%)': [
#         41.19, 33.12, 32.10, 32.63, 36.28, 40.30, 26.15, 20.84, 21.22, 17.36,
#         32.75, 23.09, 15.28, 12.80, 12.77, 5.38, 11.80, 12.18, 9.93, 9.44,
#         5.18, 15.82, 21.42
#     ],
#     '2008 (%)': [
#         41.24, 26.30, 29.13, 29.76, 32.78, 34.54, 22.91, 19.61, 19.60, 15.83,
#         30.15, 21.10, 14.98, 12.32, 11.30, 7.09, 10.45, 10.62, 9.14, 6.75,
#         5.44, 14.33, 19.61
#     ],
#     '2009 (%)': [
#         40.66, 27.57, 26.95, 27.13, 25.52, 27.11, 20.49, 16.71, 18.04, 13.01,
#         26.50, 18.65, 14.61, 12.07, 10.74, 7.87, 9.04, 9.39, 7.21, 6.02,
#         5.21, 12.53, 17.31
#     ],
#     '2010 (%)': [
#         37.24, 30.46, 28.00, 24.80, 22.81, 22.78, 19.05, 16.66, 15.88, 11.25,
#         24.67, 16.81, 13.17, 12.50, 10.99, 9.13, 8.53, 8.35, 7.91, 7.23,
#         5.04, 11.99, 16.33
#     ],
#     'Máximo Período (%)': [
#         31.27, 32.19, 23.21, 22.76, 22.37, 20.25, 18.27, 11.96, 17.76, 10.54,
#         22.95, 14.91, 11.69, 10.49, 9.76, 8.09, 8.30, 7.94, 7.12, 7.05,
#         5.91, 10.81, 14.83
#     ]
# }

# df = pd.DataFrame(data)

# # Convertir las columnas de años a tipo numérico
# cols_años = [col for col in df.columns if ' (%)' in col]
# for col in cols_años:
#     df[col] = pd.to_numeric(df[col], errors='coerce')

# print("DataFrame Creado (Primeras Filas):")
# print(df.head().to_markdown(index=False))

# %%
# # 4. Código Python para Plot (Gráfico de Líneas)

# # Seleccionamos las series clave para la visualización
# series_clave = ['Media Nacional', 'Total CNEL', 'Total Empresas Eléctricas']
# df_plot = df[df['Empresa/Categoría'].isin(series_clave)].set_index('Empresa/Categoría')

# # Transponer para que los años sean el índice y las series sean las columnas
# df_transposed = df_plot[cols_años].T

# # Limpiar los nombres de las columnas de la unidad ' (%)' para el eje X
# df_transposed.index = df_transposed.index.str.replace(' (%)', '')

# # Generar el gráfico de líneas
# plt.figure(figsize=(12, 7))

# # Trazar las líneas
# df_transposed.plot(kind='line', ax=plt.gca(), marker='o', linewidth=2)

# # Configurar el gráfico
# plt.title('Evolución del Porcentaje de Pérdidas de Energía (1999-2010)', fontsize=16)
# plt.xlabel('Año', fontsize=12)
# plt.ylabel('Pérdidas de Energía (%)', fontsize=12)
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.legend(title='Categoría', loc='best', fontsize=10)
# plt.xticks(rotation=45)
# plt.yticks(range(0, int(df_transposed.values.max()) + 5, 5)) # Ajustar el rango del eje Y para claridad
# plt.tight_layout()

# # Mostrar el gráfico
# plt.show()
